# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import os
import matplotlib.patches as mpatches

from scipy.interpolate import spline

# %%
sns.palplot(sns.color_palette("colorblind", 10))
sns.color_palette("colorblind", 10).as_hex()
# Out:
# ['#0173b2',
#  '#de8f05',
#  '#029e73',
#  '#d55e00',
#  '#cc78bc',
#  '#ca9161',
#  '#fbafe4',
#  '#949494',
#  '#ece133',
#  '#56b4e9']

# %%
conf = 0.5
nbins = 30
datapoints = 300
prefix = 'Q1'

# %%
input_dir = '/home/bay001/projects/kris_apobec_20200121/permanent_data/final_analysis/figure_3/inputs'
output_dir = '/home/bay001/projects/kris_apobec_20200121/permanent_data/final_analysis/figure_3/outputs'

# %%
sample13_rel_location = pd.read_csv(os.path.join(input_dir, "Sample13_S31_merged.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
sample29_rel_location = pd.read_csv(os.path.join(input_dir, "Sample29_S38_merged.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
sample30_rel_location = pd.read_csv(os.path.join(input_dir, "Sample30_S39_merged.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
sample31_rel_location = pd.read_csv(os.path.join(input_dir, "Sample31_S40_merged.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
sample32_rel_location = pd.read_csv(os.path.join(input_dir, "Sample32_S22_merged.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
sample33_rel_location = pd.read_csv(os.path.join(input_dir, "Sample_33_S61_L006_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
sample34_rel_location = pd.read_csv(os.path.join(input_dir, "Sample_34_S62_L006_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
sample35_rel_location = pd.read_csv(os.path.join(input_dir, "Sample_35_S63_L006_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
sample36_rel_location = pd.read_csv(os.path.join(input_dir, "Sample_36_S64_L006_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
sample37_rel_location = pd.read_csv(os.path.join(input_dir, "Sample_37_S65_L006_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
sample38_rel_location = pd.read_csv(os.path.join(input_dir, "Sample_38_S66_L006_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
sample39_rel_location = pd.read_csv(os.path.join(input_dir, "Sample_39_S67_L006_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
sample40_rel_location = pd.read_csv(os.path.join(input_dir, "Sample_40_S68_L006_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
sample41_rel_location = pd.read_csv(os.path.join(input_dir, "Sample41_S41_merged.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
sample42_rel_location = pd.read_csv(os.path.join(input_dir, 'Sample42_S42_merged.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt'.format(conf, prefix)), sep=' ')

rps2_r1_rel_location = pd.read_csv(os.path.join(input_dir, 'Sample41_S41_merged.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt'.format(conf, prefix)), sep=' ')
rps2_r2_rel_location = pd.read_csv(os.path.join(input_dir, 'Sample42_S42_merged.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt'.format(conf, prefix)), sep=' ')

# rps2_rel_location = pd.read_csv(os.path.join(input_dir, 'RPS2-1000_S18_L002_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt'.format(conf, prefix)), sep=' ')
# apo_rel_location = pd.read_csv(os.path.join(input_dir, 'ApoControl-1000_S21_L002_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt'.format(conf, prefix)), sep=' ')
# rbfox2_rel_location = pd.read_csv(os.path.join(input_dir, 'RBFOX2-1000_S20_L002_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt'.format(conf, prefix)), sep=' ')
rps2_rel_location = pd.read_csv(os.path.join(input_dir, 'RPS2-1000_S18_L002_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.Riboseq2.{}.dist.measures.txt.rel_location.txt'.format(conf, prefix)), sep=' ')
apo_rel_location = pd.read_csv(os.path.join(input_dir, 'ApoControl-1000_S21_L002_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.Riboseq2.{}.dist.measures.txt.rel_location.txt'.format(conf, prefix)), sep=' ')
rbfox2_rel_location = pd.read_csv(os.path.join(input_dir, 'RBFOX2-1000_S20_L002_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.Riboseq2.{}.dist.measures.txt.rel_location.txt'.format(conf, prefix)), sep=' ')

etf1_rel_location = pd.read_csv(os.path.join(input_dir, 'ETF1-1000_S16_L002_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt'.format(conf, prefix)), sep=' ')
gstp1_rel_location = pd.read_csv(os.path.join(input_dir, 'GSTP1-1000_S17_L002_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt'.format(conf, prefix)), sep=' ')
abce1_rel_location = pd.read_csv(os.path.join(input_dir, 'ABCE1-1000_S15_L002_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt'.format(conf, prefix)), sep=' ')
tia1_r1_rel_location = pd.read_csv(os.path.join(input_dir, 'Tia1_1000ng_1_S14_L001_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt'.format(conf, prefix)), sep=' ')
tia1_r2_rel_location = pd.read_csv(os.path.join(input_dir, 'Tia1_1000ng_2_S27_L002_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt'.format(conf, prefix)), sep=' ')

ti_55_10m_rel_location = pd.read_csv(os.path.join(input_dir, "TI_55_S13_L001_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.10M_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
ti_56_rel_location = pd.read_csv(os.path.join(input_dir, "TI_56_S14_L001_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
ti_58_10m_rel_location = pd.read_csv(os.path.join(input_dir, "TI_58_S15_L001_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.10M_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
ti_59_10m_rel_location = pd.read_csv(os.path.join(input_dir, "TI_59_S16_L001_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.10M_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
sample37_10m_rel_location = pd.read_csv(os.path.join(input_dir, "Sample_37_S65_L006_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.10M_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
sample38_10m_rel_location = pd.read_csv(os.path.join(input_dir, "Sample_38_S66_L006_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.10M_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')

ti_55_10m_ires_rel_location = pd.read_csv(os.path.join(input_dir, "TI_55_S13_L001_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.10M_a0_b0_e0.01.conf{}.GSE112353_Riboseq.IRES.dist.measures.txt.rel_location.txt".format(conf)), sep=' ')
ti_56_ires_rel_location = pd.read_csv(os.path.join(input_dir, "TI_56_S14_L001_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.IRES.dist.measures.txt.rel_location.txt".format(conf)), sep=' ')
sample37_10m_ires_rel_location = pd.read_csv(os.path.join(input_dir, "Sample_37_S65_L006_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.10M_a0_b0_e0.01.conf{}.GSE112353_Riboseq.IRES.dist.measures.txt.rel_location.txt".format(conf)), sep=' ')
sample38_10m_ires_rel_location = pd.read_csv(os.path.join(input_dir, "Sample_38_S66_L006_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.10M_a0_b0_e0.01.conf{}.GSE112353_Riboseq.IRES.dist.measures.txt.rel_location.txt".format(conf)), sep=' ')

ti_58_10m_torin_rel_location = pd.read_csv(os.path.join(input_dir, "TI_58_S15_L001_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.10M_a0_b0_e0.01.conf{}.GSE112353_Riboseq.TORIN.dist.measures.txt.rel_location.txt".format(conf)), sep=' ')
ti_59_10m_torin_rel_location = pd.read_csv(os.path.join(input_dir, "TI_59_S16_L001_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.10M_a0_b0_e0.01.conf{}.GSE112353_Riboseq.TORIN.dist.measures.txt.rel_location.txt".format(conf)), sep=' ')
ti_55_10m_torin_rel_location = pd.read_csv(os.path.join(input_dir, "TI_55_S13_L001_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.10M_a0_b0_e0.01.conf{}.GSE112353_Riboseq.TORIN.dist.measures.txt.rel_location.txt".format(conf)), sep=' ')
ti_56_torin_rel_location = pd.read_csv(os.path.join(input_dir, "TI_56_S14_L001_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.TORIN.dist.measures.txt.rel_location.txt".format(conf)), sep=' ')
sample37_10m_torin_rel_location = pd.read_csv(os.path.join(input_dir, "Sample_37_S65_L006_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.10M_a0_b0_e0.01.conf{}.GSE112353_Riboseq.TORIN.dist.measures.txt.rel_location.txt".format(conf)), sep=' ')
sample38_10m_torin_rel_location = pd.read_csv(os.path.join(input_dir, "Sample_38_S66_L006_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.10M_a0_b0_e0.01.conf{}.GSE112353_Riboseq.TORIN.dist.measures.txt.rel_location.txt".format(conf)), sep=' ')

rps2_21m_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2-1000_S18_L002_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.21M_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
apo_21m_rel_location = pd.read_csv(os.path.join(input_dir, "ApoControl-1000_S21_L002_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.21M_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
sample37_21m_rel_location = pd.read_csv(os.path.join(input_dir, "Sample_37_S65_L006_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.21M_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')

# apobec_plusT_1_rel_location = pd.read_csv(os.path.join(input_dir, "Apobec_plusT_1_S30_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
# apobec_plusT_2_rel_location = pd.read_csv(os.path.join(input_dir, "Apobec_plusT_2_S31_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
# apobec_T_1_rel_location = pd.read_csv(os.path.join(input_dir, "Apobec-T_1_S28_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
# apobec_T_2_rel_location = pd.read_csv(os.path.join(input_dir, "Apobec-T_2_S29_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
# rps2_plusT_1_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2_plusT_1_S38_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
# rps2_plusT_2_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2_plusT_2_S39_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
# rps2_T_1_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2-T_1_S36_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
# rps2_T_2_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2-T_2_S37_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
apobec_plusT_1_rel_location = pd.read_csv(os.path.join(input_dir, "Apobec_plusT_1_S30_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.Riboseq2.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
apobec_plusT_2_rel_location = pd.read_csv(os.path.join(input_dir, "Apobec_plusT_2_S31_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.Riboseq2.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
apobec_T_1_rel_location = pd.read_csv(os.path.join(input_dir, "Apobec-T_1_S28_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.Riboseq2.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
apobec_T_2_rel_location = pd.read_csv(os.path.join(input_dir, "Apobec-T_2_S29_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.Riboseq2.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
rps2_plusT_1_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2_plusT_1_S38_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.Riboseq2.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
rps2_plusT_2_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2_plusT_2_S39_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.Riboseq2.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
rps2_T_1_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2-T_1_S36_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.Riboseq2.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
rps2_T_2_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2-T_2_S37_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.Riboseq2.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')

# TORIN

apobec_plusT_1_torin_rel_location = pd.read_csv(os.path.join(input_dir, "Apobec_plusT_1_S30_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, "TORIN")), sep=' ')
apobec_plusT_2_torin_rel_location = pd.read_csv(os.path.join(input_dir, "Apobec_plusT_2_S31_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, "TORIN")), sep=' ')
apobec_T_1_torin_rel_location = pd.read_csv(os.path.join(input_dir, "Apobec-T_1_S28_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, "TORIN")), sep=' ')
apobec_T_2_torin_rel_location = pd.read_csv(os.path.join(input_dir, "Apobec-T_2_S29_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, "TORIN")), sep=' ')
rps2_plusT_1_torin_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2_plusT_1_S38_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, "TORIN")), sep=' ')
rps2_plusT_2_torin_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2_plusT_2_S39_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, "TORIN")), sep=' ')
rps2_T_1_torin_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2-T_1_S36_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, "TORIN")), sep=' ')
rps2_T_2_torin_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2-T_2_S37_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, "TORIN")), sep=' ')

# IRES

apobec_plusT_1_ires_rel_location = pd.read_csv(os.path.join(input_dir, "Apobec_plusT_1_S30_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, "IRES")), sep=' ')
apobec_plusT_2_ires_rel_location = pd.read_csv(os.path.join(input_dir, "Apobec_plusT_2_S31_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, "IRES")), sep=' ')
apobec_T_1_ires_rel_location = pd.read_csv(os.path.join(input_dir, "Apobec-T_1_S28_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, "IRES")), sep=' ')
apobec_T_2_ires_rel_location = pd.read_csv(os.path.join(input_dir, "Apobec-T_2_S29_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, "IRES")), sep=' ')
rps2_plusT_1_ires_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2_plusT_1_S38_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, "IRES")), sep=' ')
rps2_plusT_2_ires_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2_plusT_2_S39_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, "IRES")), sep=' ')
rps2_T_1_ires_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2-T_1_S36_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, "IRES")), sep=' ')
rps2_T_2_ires_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2-T_2_S37_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, "IRES")), sep=' ')

# single-cell

# barcode6 = pd.read_csv(os.path.join(input_dir, "RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_possorted_genome_bam_MD-6_barcodes.tsv.fx.conf0.5.GSE112353_Riboseq.Q1.dist.measures.txt.rel_location.txt"), sep=' ')
# barcode7 = pd.read_csv(os.path.join(input_dir, "RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_possorted_genome_bam_MD-7_barcodes.tsv.fx.conf0.5.GSE112353_Riboseq.Q1.dist.measures.txt.rel_location.txt"), sep=' ')
# apobec_stamp = pd.read_csv(os.path.join(input_dir, "APOBEC-STAMP_possorted_genome_bam-APOBEC_STAMP_Apo_filtered_lenti_common_expression_barcodes.txt.fx.conf0.5.GSE112353_Riboseq.Q1.dist.measures.txt.rel_location.txt"), sep=' ')
# rps2_stamp = pd.read_csv(os.path.join(input_dir, "RPS2-STAMP_possorted_genome_bam-RPS2_STAMP_Apo_filtered_lenti_common_expression_barcodes.txt.fx.conf0.5.GSE112353_Riboseq.Q1.dist.measures.txt.rel_location.txt"), sep=' ')

barcode6 = pd.read_csv(os.path.join(input_dir, "RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_possorted_genome_bam_MD-6_barcodes.tsv.fx.conf0.5.Riboseq2.Q1.dist.measures.txt.rel_location.txt"), sep=' ')
barcode7 = pd.read_csv(os.path.join(input_dir, "RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_possorted_genome_bam_MD-7_barcodes.tsv.fx.conf0.5.Riboseq2.Q1.dist.measures.txt.rel_location.txt"), sep=' ')
apobec_stamp = pd.read_csv(os.path.join(input_dir, "APOBEC-STAMP_possorted_genome_bam-APOBEC_STAMP_Apo_filtered_lenti_common_expression_barcodes.txt.fx.conf0.5.Riboseq2.Q1.dist.measures.txt.rel_location.txt"), sep=' ')
rps2_stamp = pd.read_csv(os.path.join(input_dir, "RPS2-STAMP_possorted_genome_bam-RPS2_STAMP_Apo_filtered_lenti_common_expression_barcodes.txt.fx.conf0.5.Riboseq2.Q1.dist.measures.txt.rel_location.txt"), sep=' ')

# %%
colors = sns.color_palette("hls", 8)
sns.palplot(sns.color_palette("hls", 8))
sns.color_palette("hls", 8).as_hex()
# Out:
# ['#db5f57',
#  '#dbc257',
#  '#91db57',
#  '#57db80',
#  '#57d3db',
#  '#5770db',
#  '#a157db',
#  '#db57b2']

# %% [markdown]
# # Plot all 'deep' datasets

# %%
def plot_unscaled_hist(series, label, color, ax, ax2=None, alpha=0.5, datapoints=datapoints, nbins=nbins, hist_alpha=0.1):
    sns.distplot(
        series, 
        ax=ax, 
        kde=False,
        hist_kws={"density":False, "alpha":hist_alpha}, 
        bins=nbins,
        color=color,
    )
    """sns.distplot(
        series, 
        ax=ax2, 
        kde_kws={"alpha": alpha},
        hist_kws={"density":True, "alpha":0.}, 
        bins=nbins,
        color=color
    )"""
    legend_patch = mpatches.Patch(color=color, label=label)
    n, bins, patches = plt.hist(series, bins=nbins, alpha=0, color=color)
    n = np.append(n, 0)
    power = n
    T = bins
    xnew = np.linspace(T.min(),T.max(), datapoints) #300 represents number of points to make between T.min and T.max
    power_smooth = spline(T, power, xnew)
    ax.plot(xnew,power_smooth, alpha=0.7, label=label, color=color)
    return ax, legend_patch

fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlim(0, 3)
ax2 = None # ax.twinx()

"""_, rps2_r1_patch = plot_unscaled_hist(
    series=sample41_rel_location['x'],
    label='RPS2 (Sample41) n={}'.format(sample41_rel_location.shape[0]),
    color=colors[0],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)
_, rps2_r2_patch = plot_unscaled_hist(
    series=sample42_rel_location['x'],
    label='RPS2 (Sample42) n={}'.format(sample42_rel_location.shape[0]),
    color=colors[1],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)
"""
_, rps2_patch = plot_unscaled_hist(
    series=rps2_rel_location['x'],
    label='RPS2 n={}'.format(rps2_rel_location.shape[0]),
    color="#029e73",
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, apobec_patch = plot_unscaled_hist(
    series=apo_rel_location['x'],
    label='APOBEC n={}'.format(apo_rel_location['x'].shape[0]),
    color="#de8f05",
    ax=ax,
    ax2=ax2
)
"""_, etf1_patch = plot_unscaled_hist(
    series=etf1_rel_location['x'],
    label='ETF1 n={}'.format(etf1_rel_location['x'].shape[0]),
    color=colors[3],
    ax=ax,
    ax2=ax2
)
_, abce1_patch = plot_unscaled_hist(
    series=etf1_rel_location['x'],
    label='ABCE1 n={}'.format(abce1_rel_location['x'].shape[0]),
    color=colors[4],
    ax=ax,
    ax2=ax2
)
_, gstp1_patch = plot_unscaled_hist(
    series=gstp1_rel_location['x'],
    label='GSTP1 n={}'.format(gstp1_rel_location['x'].shape[0]),
    color="#cc78bc",
    ax=ax,
    ax2=ax2
)
_, tia1_patch = plot_unscaled_hist(
    series=tia1_r1_rel_location['x'],
    label='TIA1 n={}'.format(tia1_r1_rel_location.shape[0]),
    color=colors[6],
    ax=ax,
    ax2=ax2
)"""
_, rbfox2_patch = plot_unscaled_hist(
    series=rbfox2_rel_location['x'],
    label='RBFOX2 n={}'.format(rbfox2_rel_location.shape[0]),
    color="#0173b2",
    ax=ax,
    ax2=ax2
)

handles = [rps2_patch, apobec_patch, rbfox2_patch]
ax.legend(handles=handles, loc='upper left')
ax.set_xlabel("5'UTR/CDS/3'UTR Metagene")
ax.set_ylabel("Edit number (Unscaled)")
ax.axvline(1, alpha=0.3)
ax.axvline(2, alpha=0.3)

# ax2.set_ylabel("Normalized ")
ax.set_xlim(0, 3)
fig.suptitle("Number of edits (conf={}) intersecting {} genes".format(conf, prefix))
fig.savefig(os.path.join(output_dir, "metagene_conf{}_{}_genes.svg".format(conf, prefix)))
# Out:
# /projects/ps-yeolab4/software/yeolabconda3/envs/python3essential-0.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %% [markdown]
# # Plot all "Sample" datasets

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlim(0, 3)
ax2 = ax.twinx()
_, sample13_patch = plot_unscaled_hist(
    series=sample13_rel_location['x'],
    label='Apo 1000 72h n={}'.format(sample13_rel_location.shape[0]),
    color=colors[0],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample29_patch = plot_unscaled_hist(
    series=sample29_rel_location['x'],
    label='RPS2 0 0h n={}'.format(sample29_rel_location.shape[0]),
    color=colors[1],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample31_patch = plot_unscaled_hist(
    series=sample31_rel_location['x'],
    label='RPS2 50 24h n={}'.format(sample31_rel_location.shape[0]),
    color=colors[2],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample33_patch = plot_unscaled_hist(
    series=sample33_rel_location['x'],
    label='RPS2 1000 24h n={}'.format(sample33_rel_location.shape[0]),
    color=colors[3],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample35_patch = plot_unscaled_hist(
    series=sample35_rel_location['x'],
    label='RPS2 50 48h n={}'.format(sample35_rel_location.shape[0]),
    color=colors[4],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample37_patch = plot_unscaled_hist(
    series=sample37_rel_location['x'],
    label='RPS2 1000 48h n={}'.format(sample37_rel_location.shape[0]),
    color=colors[5],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample39_patch = plot_unscaled_hist(
    series=sample39_rel_location['x'],
    label='RPS2 50 72h n={}'.format(sample39_rel_location.shape[0]),
    color=colors[6],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample41_patch = plot_unscaled_hist(
    series=sample41_rel_location['x'],
    label='RPS2 1000 72h n={}'.format(sample41_rel_location.shape[0]),
    color=colors[7],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

handles = [sample13_patch, sample29_patch, sample31_patch, sample33_patch, sample35_patch, sample37_patch, sample39_patch, sample41_patch]
ax.legend(handles=handles, loc='upper left')
ax.set_xlabel("5'UTR/CDS/3'UTR Metagene")
ax.set_ylabel("Edit number (Unscaled)")
ax.axvline(1, alpha=0.3)
ax.axvline(2, alpha=0.3)

ax2.set_ylabel("Normalized ")
ax.set_xlim(0, 3)
fig.suptitle("Number of edits (conf={}) intersecting {} genes".format(conf, prefix))
# fig.savefig("metagene_conf{}_{}_genes.svg".format(conf, prefix))
# Out:
# /projects/ps-yeolab4/software/yeolabconda3/envs/python3essential-0.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
# Text(0.5, 0.98, 'Number of edits (conf=0.5) intersecting Q1 genes')

# %% [markdown]
# # Plot "Sample" datasets at RPS2 50ng at each timepoint.

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlim(0, 3)
ax2 = ax.twinx()
_, sample13_patch = plot_unscaled_hist(
    series=sample13_rel_location['x'],
    label='Apo 1000 72h n={}'.format(sample13_rel_location.shape[0]),
    color=colors[0],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample31_patch = plot_unscaled_hist(
    series=sample31_rel_location['x'],
    label='RPS2 50 24h n={}'.format(sample31_rel_location.shape[0]),
    color=colors[2],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample35_patch = plot_unscaled_hist(
    series=sample35_rel_location['x'],
    label='RPS2 50 48h n={}'.format(sample35_rel_location.shape[0]),
    color=colors[4],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample39_patch = plot_unscaled_hist(
    series=sample39_rel_location['x'],
    label='RPS2 50 72h n={}'.format(sample39_rel_location.shape[0]),
    color=colors[6],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

handles = [sample13_patch, sample31_patch, sample35_patch, sample39_patch]
ax.legend(handles=handles, loc='upper left')
ax.set_xlabel("5'UTR/CDS/3'UTR Metagene")
ax.set_ylabel("Edit number (Unscaled)")
ax.axvline(1, alpha=0.3)
ax.axvline(2, alpha=0.3)

ax2.set_ylabel("Normalized ")
ax.set_xlim(0, 3)
fig.suptitle("Number of edits (conf={}) intersecting {} genes".format(conf, prefix))
# fig.savefig("metagene_conf{}_{}_genes.svg".format(conf, prefix))
# Out:
# /projects/ps-yeolab4/software/yeolabconda3/envs/python3essential-0.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
# Text(0.5, 0.98, 'Number of edits (conf=0.5) intersecting Q1 genes')

# %% [markdown]
# # Plot "Sample" datasets at RPS2 1000ng at each timepoint.
# - This difference is mainly due to large disparity in read coverage. We need to downsample.

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlim(0, 3)
ax2 = ax.twinx()

_, sample33_patch = plot_unscaled_hist(
    series=sample33_rel_location['x'],
    label='RPS2 1000 24h n={}'.format(sample33_rel_location.shape[0]),
    color=colors[3],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample37_patch = plot_unscaled_hist(
    series=sample37_rel_location['x'],
    label='RPS2 1000 48h n={}'.format(sample37_rel_location.shape[0]),
    color=colors[5],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample41_patch = plot_unscaled_hist(
    series=sample41_rel_location['x'],
    label='RPS2 1000 72h n={}'.format(sample41_rel_location.shape[0]),
    color=colors[0],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

handles = [sample33_patch, sample37_patch, sample41_patch]
ax.legend(handles=handles, loc='upper left')
ax.set_xlabel("5'UTR/CDS/3'UTR Metagene")
ax.set_ylabel("Edit number (Unscaled)")
ax.axvline(1, alpha=0.3)
ax.axvline(2, alpha=0.3)

ax2.set_ylabel("Normalized ")
ax.set_xlim(0, 3)
fig.suptitle("Number of edits (conf={}) intersecting {} genes".format(conf, prefix))
# fig.savefig("metagene_conf{}_{}_genes.svg".format(conf, prefix))
# Out:
# /projects/ps-yeolab4/software/yeolabconda3/envs/python3essential-0.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
# Text(0.5, 0.98, 'Number of edits (conf=0.5) intersecting Q1 genes')

# %% [markdown]
# # Plot RPS2 1000ng 48hr replicates. Seems to be a little batchy among timepoints so make sure the replicates reproduce at least.

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlim(0, 3)
ax2 = ax.twinx()

_, sample37_patch = plot_unscaled_hist(
    series=sample37_rel_location['x'],
    label='RPS2 1000 48h n={}'.format(sample37_rel_location.shape[0]),
    color=colors[5],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample38_patch = plot_unscaled_hist(
    series=sample38_rel_location['x'],
    label='RPS2 1000 48h n={}'.format(sample38_rel_location.shape[0]),
    color=colors[0],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

handles = [sample37_patch, sample38_patch]
ax.legend(handles=handles, loc='upper left')
ax.set_xlabel("5'UTR/CDS/3'UTR Metagene")
ax.set_ylabel("Edit number (Unscaled)")
ax.axvline(1, alpha=0.3)
ax.axvline(2, alpha=0.3)

ax2.set_ylabel("Normalized ")
ax.set_xlim(0, 3)
fig.suptitle("Number of edits (conf={}) intersecting {} genes".format(conf, prefix))
# fig.savefig("metagene_conf{}_{}_genes.svg".format(conf, prefix))
# Out:
# /projects/ps-yeolab4/software/yeolabconda3/envs/python3essential-0.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
# Text(0.5, 0.98, 'Number of edits (conf=0.5) intersecting Q1 genes')

# %% [markdown]
# # TI55/56 vs Sample37/38
# -  I think we should try the metagene plot with 10M 37 38 TI_55, 56 on riboseq Q1 conf 0.5.  would be cool if 55, 56 had signal shifted away from CDS and into 3’UTR.  even just lower signal across the genes would be cool.

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlim(0, 3)
ax2 = ax.twinx()

_, ti_55_patch = plot_unscaled_hist(
    series=ti_55_10m_rel_location['x'],
    label='TI 55 (10M) n={}'.format(ti_55_10m_rel_location.shape[0]),
    color='lightgrey',
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, ti_56_patch = plot_unscaled_hist(
    series=ti_56_rel_location['x'],
    label='TI 56 (10M) n={}'.format(ti_56_rel_location.shape[0]),
    color='dimgrey',
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample37_patch = plot_unscaled_hist(
    series=sample37_10m_rel_location['x'],
    label='Sample37 (10M) n={}'.format(sample37_10m_rel_location.shape[0]),
    color='#46B999',
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample38_patch = plot_unscaled_hist(
    series=sample38_10m_rel_location['x'],
    label='Sample38 (10M) n={}'.format(sample38_10m_rel_location.shape[0]),
    color='#006247',
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

handles = [ti_55_patch, ti_56_patch, sample37_patch, sample38_patch]
ax.legend(handles=handles, loc='upper left')
ax.set_xlabel("5'UTR/CDS/3'UTR Metagene")
ax.set_ylabel("Edit number (Unscaled)")
ax.axvline(1, alpha=0.3)
ax.axvline(2, alpha=0.3)

ax2.set_ylabel("Normalized ")
ax.set_xlim(0, 3)
fig.suptitle("Number of edits (conf={}) intersecting {} genes".format(conf, prefix))
fig.savefig(os.path.join(output_dir, "metagene_TI55_TI56_S37_S38_conf{}_{}_genes.svg".format(conf, prefix)))
# Out:
# /projects/ps-yeolab4/software/yeolabconda3/envs/python3essential-0.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %% [markdown]
# # if we can check those 20 IRES genes and they don’t have the same CDS drop that would be really nice. 58, 59 v 37 38 downsampled i mean, same as here.

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlim(0, 3)
ax2 = ax.twinx()

_, ti_55_patch = plot_unscaled_hist(
    series=ti_55_10m_ires_rel_location['x'],
    label='TI 55 (10M) n={}'.format(ti_55_10m_ires_rel_location.shape[0]),
    color=colors[0],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, ti_56_patch = plot_unscaled_hist(
    series=ti_56_ires_rel_location['x'],
    label='TI 56 (10M) n={}'.format(ti_56_ires_rel_location.shape[0]),
    color=colors[1],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample37_patch = plot_unscaled_hist(
    series=sample37_10m_ires_rel_location['x'],
    label='Sample37 (10M) n={}'.format(sample37_10m_ires_rel_location.shape[0]),
    color=colors[2],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample38_patch = plot_unscaled_hist(
    series=sample38_10m_ires_rel_location['x'],
    label='Sample38 (10M) n={}'.format(sample38_10m_ires_rel_location.shape[0]),
    color=colors[3],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

handles = [ti_55_patch, ti_56_patch, sample37_patch, sample38_patch]
ax.legend(handles=handles, loc='upper left')
ax.set_xlabel("5'UTR/CDS/3'UTR Metagene")
ax.set_ylabel("Edit number (Unscaled)")
ax.axvline(1, alpha=0.3)
ax.axvline(2, alpha=0.3)

ax2.set_ylabel("Normalized ")
ax.set_xlim(0, 3)
fig.suptitle("Number of edits (conf={}) intersecting {} genes".format(conf, "IRES"))
fig.savefig(os.path.join(output_dir, "metagene_TI55_TI56_S37_S38_conf{}_{}_genes.svg".format(conf, "IRES")))
# Out:
# /projects/ps-yeolab4/software/yeolabconda3/envs/python3essential-0.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %% [markdown]
# #  last thing to box plot is 37 38 v 58 59 10M sets to make sure they either don’t change much or hopefully go up slightly in Q1.

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlim(0, 3)
ax2 = ax.twinx()

_, ti_58_patch = plot_unscaled_hist(
    series=ti_58_10m_rel_location['x'],
    label='TI 58 (10M) n={}'.format(ti_58_10m_rel_location.shape[0]),
    color=colors[0],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, ti_59_patch = plot_unscaled_hist(
    series=ti_59_10m_rel_location['x'],
    label='TI 59 (10M) n={}'.format(ti_59_10m_rel_location.shape[0]),
    color=colors[1],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample37_patch = plot_unscaled_hist(
    series=sample37_10m_rel_location['x'],
    label='Sample37 (10M) n={}'.format(sample37_10m_rel_location.shape[0]),
    color=colors[2],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample38_patch = plot_unscaled_hist(
    series=sample38_10m_rel_location['x'],
    label='Sample38 (10M) n={}'.format(sample38_10m_rel_location.shape[0]),
    color=colors[3],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

handles = [ti_58_patch, ti_59_patch, sample37_patch, sample38_patch]
ax.legend(handles=handles, loc='upper left')
ax.set_xlabel("5'UTR/CDS/3'UTR Metagene")
ax.set_ylabel("Edit number (Unscaled)")
ax.axvline(1, alpha=0.3)
ax.axvline(2, alpha=0.3)

ax2.set_ylabel("Normalized ")
ax.set_xlim(0, 3)
fig.suptitle("Number of edits (conf={}) intersecting {} genes".format(conf, prefix))
fig.savefig(os.path.join(output_dir, "metagene_TI58_TI59_S37_S38_conf{}_{}_genes.svg".format(conf, prefix)))
# Out:
# /projects/ps-yeolab4/software/yeolabconda3/envs/python3essential-0.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlim(0, 3)
ax2 = ax.twinx()


_, sample34_patch = plot_unscaled_hist(
    series=sample34_rel_location['x'],
    label='Sample34 (all) n={}'.format(sample34_rel_location.shape[0]),
    color=colors[0],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample37_patch = plot_unscaled_hist(
    series=sample37_21m_rel_location['x'],
    label='Sample37 (21M) n={}'.format(sample37_21m_rel_location.shape[0]),
    color=colors[1],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, rps2_patch = plot_unscaled_hist(
    series=rps2_21m_rel_location['x'],
    label='RPS2-1000 (21M) n={}'.format(rps2_21m_rel_location.shape[0]),
    color=colors[2],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, apo_patch = plot_unscaled_hist(
    series=apo_21m_rel_location['x'],
    label='APOBEC-1000 (21M) n={}'.format(apo_21m_rel_location.shape[0]),
    color=colors[4],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

handles = [sample34_patch, sample37_patch, rps2_patch, apo_patch]
ax.legend(handles=handles, loc='upper left')
ax.set_xlabel("5'UTR/CDS/3'UTR Metagene")
ax.set_ylabel("Edit number (Unscaled)")
ax.axvline(1, alpha=0.3)
ax.axvline(2, alpha=0.3)

ax2.set_ylabel("Normalized ")
ax.set_xlim(0, 3)
fig.suptitle("Number of edits (conf={}) intersecting {} genes".format(conf, prefix))
fig.savefig(os.path.join(output_dir, "metagene_S34_S37_RPS2-1000_APO-1000_21M_conf{}_{}_genes.svg".format(conf, prefix)))
# Out:
# /projects/ps-yeolab4/software/yeolabconda3/envs/python3essential-0.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlim(0, 3)
ax2 = ax.twinx()


_, sample34_patch = plot_unscaled_hist(
    series=sample34_rel_location['x'],
    label='Sample34 (all) n={}'.format(sample34_rel_location.shape[0]),
    color=colors[0],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample37_patch = plot_unscaled_hist(
    series=sample37_rel_location['x'],
    label='Sample37 (all) n={}'.format(sample37_rel_location.shape[0]),
    color=colors[1],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, rps2_patch = plot_unscaled_hist(
    series=rps2_rel_location['x'],
    label='RPS2 (1000) n={}'.format(rps2_rel_location.shape[0]),
    color=colors[2],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, apo_patch = plot_unscaled_hist(
    series=apo_rel_location['x'],
    label='APOBEC (1000) n={}'.format(apo_rel_location.shape[0]),
    color=colors[4],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

handles = [sample34_patch, sample37_patch, rps2_patch, apo_patch]
ax.legend(handles=handles, loc='upper left')
ax.set_xlabel("5'UTR/CDS/3'UTR Metagene")
ax.set_ylabel("Edit number (Unscaled)")
ax.axvline(1, alpha=0.3)
ax.axvline(2, alpha=0.3)

ax2.set_ylabel("Normalized ")
ax.set_xlim(0, 3)
fig.suptitle("Number of edits (conf={}) intersecting {} genes".format(conf, prefix))
fig.savefig(os.path.join(output_dir, "metagene_S34_S37_RPS2-1000_APO-1000_conf{}_{}_genes.svg".format(conf, prefix)))
# Out:
# /projects/ps-yeolab4/software/yeolabconda3/envs/python3essential-0.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlim(0, 3)
ax2 = ax.twinx()

_, ti_55_patch = plot_unscaled_hist(
    series=ti_55_10m_torin_rel_location['x'],
    label='TI55 (10M) n={}'.format(ti_55_10m_torin_rel_location.shape[0]),
    color=colors[0],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, ti_56_patch = plot_unscaled_hist(
    series=ti_56_torin_rel_location['x'],
    label='TI56 n={}'.format(ti_56_torin_rel_location.shape[0]),
    color=colors[1],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample37_patch = plot_unscaled_hist(
    series=sample37_10m_torin_rel_location['x'],
    label='Sample37 (10M) n={}'.format(sample37_10m_torin_rel_location.shape[0]),
    color=colors[2],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample38_patch = plot_unscaled_hist(
    series=sample38_10m_torin_rel_location['x'],
    label='Sample38 (10M) n={}'.format(sample38_10m_torin_rel_location.shape[0]),
    color=colors[4],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

handles = [ti_55_patch, ti_56_patch, sample37_patch, sample38_patch]
ax.legend(handles=handles, loc='upper left')
ax.set_xlabel("5'UTR/CDS/3'UTR Metagene")
ax.set_ylabel("Edit number (Unscaled)")
ax.axvline(1, alpha=0.3)
ax.axvline(2, alpha=0.3)

ax2.set_ylabel("Normalized ")
ax.set_xlim(0, 3)
fig.suptitle("Number of edits (conf={}) intersecting {} genes".format(conf, prefix))
fig.savefig(os.path.join(output_dir, "metagene_S37_S38_TI55_TI56_TORIN_conf{}_{}_genes.svg".format(conf, prefix)))
# Out:
# /projects/ps-yeolab4/software/yeolabconda3/envs/python3essential-0.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlim(0, 3)
ax2 = ax.twinx()

_, ti_58_patch = plot_unscaled_hist(
    series=ti_58_10m_torin_rel_location['x'],
    label='TI58 (10M) n={}'.format(ti_58_10m_torin_rel_location.shape[0]),
    color=colors[0],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, ti_59_patch = plot_unscaled_hist(
    series=ti_59_10m_torin_rel_location['x'],
    label='TI59 (10M) n={}'.format(ti_59_10m_torin_rel_location.shape[0]),
    color=colors[1],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample37_patch = plot_unscaled_hist(
    series=sample37_10m_torin_rel_location['x'],
    label='Sample37 (10M) n={}'.format(sample37_10m_torin_rel_location.shape[0]),
    color=colors[2],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, sample38_patch = plot_unscaled_hist(
    series=sample38_10m_torin_rel_location['x'],
    label='Sample38 (10M) n={}'.format(sample38_10m_torin_rel_location.shape[0]),
    color=colors[4],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

handles = [ti_58_patch, ti_59_patch, sample37_patch, sample38_patch]
ax.legend(handles=handles, loc='upper left')
ax.set_xlabel("5'UTR/CDS/3'UTR Metagene")
ax.set_ylabel("Edit number (Unscaled)")
ax.axvline(1, alpha=0.3)
ax.axvline(2, alpha=0.3)

ax2.set_ylabel("Normalized ")
ax.set_xlim(0, 3)
fig.suptitle("Number of edits (conf={}) intersecting {} genes".format(conf, prefix))
fig.savefig(os.path.join(output_dir, "metagene_S37_S38_TI58_TI59_TORIN_conf{}_{}_genes.svg".format(conf, prefix)))
# Out:
# /projects/ps-yeolab4/software/yeolabconda3/envs/python3essential-0.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
apobec_plusT_1_rel_location = pd.read_csv(os.path.join(input_dir, "Apobec_plusT_1_S30_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
apobec_plusT_2_rel_location = pd.read_csv(os.path.join(input_dir, "Apobec_plusT_2_S31_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
apobec_T_1_rel_location = pd.read_csv(os.path.join(input_dir, "Apobec-T_1_S28_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
apobec_T_2_rel_location = pd.read_csv(os.path.join(input_dir, "Apobec-T_2_S29_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
rps2_plusT_1_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2_plusT_1_S38_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
rps2_plusT_2_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2_plusT_2_S39_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
rps2_T_1_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2-T_1_S36_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')
rps2_T_2_rel_location = pd.read_csv(os.path.join(input_dir, "RPS2-T_2_S37_L003_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf{}.GSE112353_Riboseq.{}.dist.measures.txt.rel_location.txt".format(conf, prefix)), sep=' ')

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlim(0, 3)
ax2 = ax.twinx()

_, apo_plus_t_r1_patch = plot_unscaled_hist(
    series=apobec_plusT_1_rel_location['x'],
    label='Apobec_plusT_1 n={}'.format(apobec_plusT_1_rel_location.shape[0]),
    color=colors[0],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)
_, apo_plus_t_r2_patch = plot_unscaled_hist(
    series=apobec_plusT_2_rel_location['x'],
    label='Apobec_plusT_2 n={}'.format(apobec_plusT_2_rel_location.shape[0]),
    color=colors[1],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)
_, apo_t_r1_patch = plot_unscaled_hist(
    series=apobec_T_1_rel_location['x'],
    label='Apobec_T_1 n={}'.format(apobec_T_1_rel_location.shape[0]),
    color=colors[2],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)
_, apo_t_r2_patch = plot_unscaled_hist(
    series=apobec_T_2_rel_location['x'],
    label='Apobec_T_2 n={}'.format(apobec_T_2_rel_location.shape[0]),
    color=colors[3],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, rps2_plus_t_r1_patch = plot_unscaled_hist(
    series=rps2_plusT_1_rel_location['x'],
    label='RPS2_plusT_1 n={}'.format(rps2_plusT_1_rel_location.shape[0]),
    color=colors[4],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, rps2_plus_t_r2_patch = plot_unscaled_hist(
    series=rps2_plusT_2_rel_location['x'],
    label='RPS2_plusT_2 n={}'.format(rps2_plusT_2_rel_location.shape[0]),
    color=colors[5],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, rps2_t_r1_patch = plot_unscaled_hist(
    series=rps2_T_1_rel_location['x'],
    label='RPS2_T_1 n={}'.format(rps2_T_1_rel_location.shape[0]),
    color=colors[6],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, rps2_t_r2_patch = plot_unscaled_hist(
    series=rps2_T_2_rel_location['x'],
    label='RPS2_T_2 n={}'.format(rps2_T_2_rel_location.shape[0]),
    color=colors[7],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

handles = [
    apo_plus_t_r1_patch, apo_plus_t_r2_patch, apo_t_r1_patch, apo_t_r2_patch, 
    rps2_plus_t_r1_patch, rps2_plus_t_r2_patch, rps2_t_r1_patch, rps2_t_r2_patch
]
ax.legend(handles=handles, loc='upper left')
ax.set_xlabel("5'UTR/CDS/3'UTR Metagene")
ax.set_ylabel("Edit number (Unscaled)")
ax.axvline(1, alpha=0.3)
ax.axvline(2, alpha=0.3)

ax2.set_ylabel("Normalized ")
ax.set_xlim(0, 3)
fig.suptitle("Number of edits (conf={}) intersecting {} genes".format(conf, prefix))
fig.savefig(os.path.join(output_dir, "metagene_plusT_vs_T_conf{}_{}_genes.svg".format(conf, prefix)))
# Out:
# /projects/ps-yeolab4/software/yeolabconda3/envs/python3essential-0.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlim(0, 3)
ax2 = ax.twinx()

_, apo_plus_t_r1_patch = plot_unscaled_hist(
    series=apobec_plusT_1_torin_rel_location['x'],
    label='Apobec_plusT_1 n={}'.format(apobec_plusT_1_torin_rel_location.shape[0]),
    color=colors[0],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)
_, apo_plus_t_r2_patch = plot_unscaled_hist(
    series=apobec_plusT_2_torin_rel_location['x'],
    label='Apobec_plusT_2 n={}'.format(apobec_plusT_2_torin_rel_location.shape[0]),
    color=colors[1],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)
_, apo_t_r1_patch = plot_unscaled_hist(
    series=apobec_T_1_torin_rel_location['x'],
    label='Apobec_T_1 n={}'.format(apobec_T_1_torin_rel_location.shape[0]),
    color=colors[2],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)
_, apo_t_r2_patch = plot_unscaled_hist(
    series=apobec_T_2_torin_rel_location['x'],
    label='Apobec_T_2 n={}'.format(apobec_T_2_torin_rel_location.shape[0]),
    color=colors[3],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, rps2_plus_t_r1_patch = plot_unscaled_hist(
    series=rps2_plusT_1_torin_rel_location['x'],
    label='RPS2_plusT_1 n={}'.format(rps2_plusT_1_torin_rel_location.shape[0]),
    color=colors[4],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, rps2_plus_t_r2_patch = plot_unscaled_hist(
    series=rps2_plusT_2_torin_rel_location['x'],
    label='RPS2_plusT_2 n={}'.format(rps2_plusT_2_torin_rel_location.shape[0]),
    color=colors[5],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, rps2_t_r1_patch = plot_unscaled_hist(
    series=rps2_T_1_torin_rel_location['x'],
    label='RPS2_T_1 n={}'.format(rps2_T_1_torin_rel_location.shape[0]),
    color=colors[6],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, rps2_t_r2_patch = plot_unscaled_hist(
    series=rps2_T_2_torin_rel_location['x'],
    label='RPS2_T_2 n={}'.format(rps2_T_2_torin_rel_location.shape[0]),
    color=colors[7],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

handles = [
    apo_plus_t_r1_patch, apo_plus_t_r2_patch, apo_t_r1_patch, apo_t_r2_patch, 
    rps2_plus_t_r1_patch, rps2_plus_t_r2_patch, rps2_t_r1_patch, rps2_t_r2_patch
]
ax.legend(handles=handles, loc='upper left')
ax.set_xlabel("5'UTR/CDS/3'UTR Metagene")
ax.set_ylabel("Edit number (Unscaled)")
ax.axvline(1, alpha=0.3)
ax.axvline(2, alpha=0.3)

ax2.set_ylabel("Normalized ")
ax.set_xlim(0, 3)
fig.suptitle("Number of edits (conf={}) intersecting {} genes".format(conf, "TORIN"))
fig.savefig(os.path.join(output_dir, "metagene_plusT_vs_T_conf{}_{}_genes.svg".format(conf, "TORIN")))
# Out:
# /projects/ps-yeolab4/software/yeolabconda3/envs/python3essential-0.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlim(0, 3)
ax2 = ax.twinx()

_, apo_plus_t_r1_patch = plot_unscaled_hist(
    series=apobec_plusT_1_ires_rel_location['x'],
    label='Apobec_plusT_1 n={}'.format(apobec_plusT_1_ires_rel_location.shape[0]),
    color=colors[0],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)
_, apo_plus_t_r2_patch = plot_unscaled_hist(
    series=apobec_plusT_2_ires_rel_location['x'],
    label='Apobec_plusT_2 n={}'.format(apobec_plusT_2_ires_rel_location.shape[0]),
    color=colors[1],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)
_, apo_t_r1_patch = plot_unscaled_hist(
    series=apobec_T_1_ires_rel_location['x'],
    label='Apobec_T_1 n={}'.format(apobec_T_1_ires_rel_location.shape[0]),
    color=colors[2],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)
_, apo_t_r2_patch = plot_unscaled_hist(
    series=apobec_T_2_ires_rel_location['x'],
    label='Apobec_T_2 n={}'.format(apobec_T_2_ires_rel_location.shape[0]),
    color=colors[3],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, rps2_plus_t_r1_patch = plot_unscaled_hist(
    series=rps2_plusT_1_ires_rel_location['x'],
    label='RPS2_plusT_1 n={}'.format(rps2_plusT_1_ires_rel_location.shape[0]),
    color=colors[4],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, rps2_plus_t_r2_patch = plot_unscaled_hist(
    series=rps2_plusT_2_ires_rel_location['x'],
    label='RPS2_plusT_2 n={}'.format(rps2_plusT_2_ires_rel_location.shape[0]),
    color=colors[5],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, rps2_t_r1_patch = plot_unscaled_hist(
    series=rps2_T_1_ires_rel_location['x'],
    label='RPS2_T_1 n={}'.format(rps2_T_1_ires_rel_location.shape[0]),
    color=colors[6],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

_, rps2_t_r2_patch = plot_unscaled_hist(
    series=rps2_T_2_ires_rel_location['x'],
    label='RPS2_T_2 n={}'.format(rps2_T_2_ires_rel_location.shape[0]),
    color=colors[7],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

handles = [
    apo_plus_t_r1_patch, apo_plus_t_r2_patch, apo_t_r1_patch, apo_t_r2_patch, 
    rps2_plus_t_r1_patch, rps2_plus_t_r2_patch, rps2_t_r1_patch, rps2_t_r2_patch
]
ax.legend(handles=handles, loc='upper left')
ax.set_xlabel("5'UTR/CDS/3'UTR Metagene")
ax.set_ylabel("Edit number (Unscaled)")
ax.axvline(1, alpha=0.3)
ax.axvline(2, alpha=0.3)

ax2.set_ylabel("Normalized ")
ax.set_xlim(0, 3)
fig.suptitle("Number of edits (conf={}) intersecting {} genes".format(conf, "IRES"))
fig.savefig(os.path.join(output_dir, "metagene_plusT_vs_T_conf{}_{}_genes.svg".format(conf, "IRES")))
# Out:
# /projects/ps-yeolab4/software/yeolabconda3/envs/python3essential-0.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %% [markdown]
# # Plot the single cell stuff.

# %%
sns.palplot(sns.color_palette("colorblind", 10))
colors = sns.color_palette("colorblind", 10)

fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlim(0, 3)
ax2 = ax.twinx()

_, barcode6_patch = plot_unscaled_hist(
    series=barcode6['x'],
    label='Barcode 6 n={}'.format(barcode6.shape[0]),
    color=colors[3],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)
_, barcode7_patch = plot_unscaled_hist(
    series=barcode7['x'],
    label='barcode 7 n={}'.format(barcode7.shape[0]),
    color=colors[0],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)
_, apobec_stamp_patch = plot_unscaled_hist(
    series=apobec_stamp['x'],
    label='apobec_stamp n={}'.format(apobec_stamp.shape[0]),
    color=colors[1],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)
_, rps2_stamp_patch = plot_unscaled_hist(
    series=rps2_stamp['x'],
    label='rps2_stamp n={}'.format(rps2_stamp.shape[0]),
    color=colors[2],
    ax=ax,
    ax2=ax2,
    alpha=0.9
)

handles = [
    barcode6_patch, barcode7_patch, apobec_stamp_patch, rps2_stamp_patch, 
]
ax.legend(handles=handles, loc='upper left')
ax.set_xlabel("5'UTR/CDS/3'UTR Metagene")
ax.set_ylabel("Edit number (Unscaled)")
ax.axvline(1, alpha=0.3)
ax.axvline(2, alpha=0.3)

ax2.set_ylabel("Normalized ")
ax.set_xlim(0, 3)
fig.suptitle("Number of edits (conf={}) intersecting {} genes".format(conf, "Q1"))
fig.savefig(os.path.join(output_dir, "metagene_single_cell.svg"))
# Out:
# /projects/ps-yeolab4/software/yeolabconda3/envs/python3essential-0.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
samples = {
    "Apo-1000-72h-r1":sample13_rel_location,
    "Rps2-0-0h-r1":sample29_rel_location,
    "Rps2-0-0h-r2":sample30_rel_location,
    "Rps2-50-24h-r1":sample31_rel_location,
    "Rps2-50-24h-r2":sample32_rel_location,
    "Rps2-1000-24h-r1":sample33_rel_location,
    "Rps2-1000-24h-r2":sample34_rel_location,
    "Rps2-50-48h-r1":sample35_rel_location,
    "Rps2-50-48h-r2":sample36_rel_location,
    "Rps2-1000-48h-r1":sample37_rel_location,
    "Rps2-1000-48h-r2":sample38_rel_location,
    "Rps2-50-72h-r1":sample39_rel_location,
    "Rps2-50-72h-r2":sample40_rel_location,
    "Rps2-1000-72h-r1":sample41_rel_location,
    "Rps2-1000-72h-r2":sample42_rel_location,
}
sns.palplot(sns.color_palette("hls", len(samples)))
colors = sns.color_palette("hls", len(samples))

fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlim(0, 3)
ax2 = ax.twinx()
i = 0

handles = []
for label, sample in samples.items():
    _, patch = plot_unscaled_hist(
        series=sample['x'],
        label='{} n={}'.format(label, sample.shape[0]),
        color=colors[i],
        ax=ax,
        ax2=ax2,
        alpha=0.9,
        hist_alpha=0.05
    )
    i+=1
    handles.append(patch)
    
ax.legend(handles=handles, loc='upper left')
ax.set_xlabel("5'UTR/CDS/3'UTR Metagene")
ax.set_ylabel("Edit number (Unscaled)")
ax.axvline(1, alpha=0.3)
ax.axvline(2, alpha=0.3)

ax2.set_ylabel("Normalized ")
ax.set_xlim(0, 3)
fig.suptitle("Number of edits (conf={}) intersecting {} genes".format(conf, "Q1"))
fig.savefig(os.path.join(output_dir, "metagene_all_rps_samples.svg"))
# Out:
# /projects/ps-yeolab4/software/yeolabconda3/envs/python3essential-0.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %% [raw]
# datapoints = 300
#
# fig, ax = plt.subplots(figsize=(15, 5))
# sns.distplot(
#     rps2_rel_location,
#     ax=ax,
#     hist_kws={"density":False, "alpha":0.1},
#     bins=nbins,
#     color='black'
# )
# sns.distplot(
#     gstp1_rel_location,
#     ax=ax,
#     hist_kws={"density":False, "alpha":0.1},
#     bins=nbins,
#     color='orange'
# )
# sns.distplot(
#     apo_rel_location,
#     ax=ax,
#     hist_kws={"density":False, "alpha":0.1},
#     bins=nbins,
#     color='blue'
# )
# """# sns.distplot(rbfox2_rel_location, ax=ax, hist_kws={"density":False, "alpha":0.2}, bins=nbins, label='RBFOX2-1000', color='orange')
# sns.distplot(
#     rps2_conf_rel_location,
#     ax=ax,
#     hist_kws={"density":False, "alpha":0.1},
#     bins=nbins,
#     color='blue'
# )"""
#
# # sns.distplot(etf1_rel_location, ax=ax, hist_kws={"density":False}, bins=nbins, label='ETF1-1000')
# # sns.distplot(gstp1_rel_location, ax=ax, hist_kws={"density":False}, bins=nbins, label='GSTP1-1000')
# # sns.distplot(abce1_rel_location, ax=ax, hist_kws={"density":False}, bins=nbins, label='ABCE1-1000')
# # sns.distplot(rbfox2_rel_location, ax=ax, hist_kws={"density":False}, bins=nbins, label='RBFOX2-Sample19')
#
# n, bins, patches = plt.hist(rps2_rel_location['x'], bins=nbins, alpha=0)
# n = np.append(n, 0)
# power = n
# T = bins
# xnew = np.linspace(T.min(),T.max(), datapoints) #300 represents number of points to make between T.min and T.max
# rps2_power_smooth = spline(T,power,xnew)
# ax.plot(xnew,rps2_power_smooth, color='black', alpha=0.7, label='RPS2-1000 (conf={} n={})'.format(conf, rps2_rel_location.shape[0]))
#
# n, bins, patches = plt.hist(etf1_rel_location['x'], bins=nbins, alpha=0)
# n = np.append(n, 0)
# power = n
# T = bins
# xnew = np.linspace(T.min(),T.max(), datapoints) #300 represents number of points to make between T.min and T.max
# etf1_power_smooth = spline(T,power,xnew)
# ax.plot(xnew,etf1_power_smooth, color='green', alpha=0.3, label='ETF1-1000 (conf={} n={})'.format(conf, etf1_rel_location.shape[0]))
#
# n, bins, patches = plt.hist(apo_rel_location['x'], bins=nbins, alpha=0)
# n = np.append(n, 0)
# power = n
# T = bins
# xnew = np.linspace(T.min(),T.max(), datapoints) #300 represents number of points to make between T.min and T.max
# apo_power_smooth = spline(T,power,xnew)
# ax.plot(xnew,apo_power_smooth, color='red', alpha=0.3, label='APOBEC-1000 (conf={} n={})'.format(conf, apo_rel_location.shape[0]))
#
# n, bins, patches = plt.hist(gstp1_rel_location['x'], bins=nbins, alpha=0)
# n = np.append(n, 0)
# power = n
# T = bins
# xnew = np.linspace(T.min(),T.max(), datapoints) #300 represents number of points to make between T.min and T.max
# gstp1_power_smooth = spline(T,power,xnew)
# ax.plot(xnew,gstp1_power_smooth, color='orange', alpha=0.3, label='GSTP1-1000 (conf={} n={})'.format(conf, gstp1_rel_location.shape[0]))
#
# """n, bins, patches = plt.hist(rps2_conf_rel_location['x'], bins=nbins, alpha=0)
# n = np.append(n, 0)
# power = n
# T = bins
# rps2_conf_power_smooth = spline(T,power,xnew)
# ax.plot(xnew,rps2_conf_power_smooth, color='blue', alpha=0.3, label='RPS2-1000 (conf=0.99 n={})'.format(rps2_conf_rel_location.shape[0]))
# """
# ax.set_xlabel("5'UTR/CDS/3'UTR Metagene")
# ax.set_ylabel("Edit number (Unscaled)")
# ax.axvline(1, alpha=0.3)
# ax.axvline(2, alpha=0.3)
# ax.set_xlim(0, 3)
#
# # ax2 = ax.twinx()
#
# # ax2.plot(xnew, np.log2(rps2_power_smooth/(apo_power_smooth+1)), color='red', alpha=1, label='log2(rps2/apo)')
# # ax2.plot(xnew, np.log2(rps2_power_smooth/(rps2_conf_power_smooth+1)), color='blue', alpha=1, label='log2(rps2/rps2(conf))')
#
# # ax2.set_ylim(0, 5)
# plt.legend()
#
# fig.savefig(os.path.join(output_dir, 'histogram_edits_metagene_unscaled_conf.svg'))

# %% [raw]
# rps2_n, rps2_bins, patches = plt.hist(rps2_rel_location['x'], bins=nbins, alpha=0)
# gstp1_n, gstp1_bins, patches = plt.hist(gstp1_rel_location['x'], bins=nbins, alpha=0)

# %% [raw]
# fig, ax = plt.subplots(figsize=(15, 0.5))
# sns.heatmap(pd.DataFrame(np.log2(rps2_n/gstp1_n)).T, label='log2(rps2/gstp1)', vmin=0, vmax=max(np.log2(rps2_n/gstp1_n)), cmap='Oranges', ax=ax)
# # sns.heatmap(pd.DataFrame(np.log2(rps2_power_smooth/(rps2_conf_power_smooth+1))).T, label='log2(rps2/rps2(conf))', vmin=0, vmax=4, cmap='Blues')

# %% [raw]
# fig, ax = plt.subplots(figsize=(15, 5))
# sns.distplot(
#     rps2_rel_location,
#     ax=ax,
#     hist_kws={"density":True},
#     bins=nbins,
#     label='RPS2-1000 (conf={} n={})'.format(conf, rps2_rel_location.shape[0]),
# )
# sns.distplot(
#     apo_rel_location,
#     ax=ax,
#     hist_kws={"density":True},
#     bins=nbins,
#     label='APOBEC-1000 (conf={} n={})'.format(conf, apo_rel_location.shape[0]),
# )
# # sns.distplot(apo_rel_location, ax=ax, hist_kws={"density":True}, bins=nbins, label='APOBEC-1000')
# # sns.distplot(rbfox2_rel_location, ax=ax, hist_kws={"density":True}, bins=30, label='RBFOX2-1000')
# # sns.distplot(etf1_rel_location, ax=ax, hist_kws={"density":True}, bins=nbins, label='RPS2-1000')
# # sns.distplot(gstp1_rel_location, ax=ax, hist_kws={"density":True}, bins=nbins, label='GSTP1-1000')
# # sns.distplot(abce1_rel_location, ax=ax, hist_kws={"density":True}, bins=30, label='RBFOX2-1000')
# sns.distplot(
#     rps2_conf_rel_location,
#     ax=ax,
#     hist_kws={"density":True},
#     bins=30,
#     label='RPS2-1000 (conf=0.999 n={})'.format(rps2_conf_rel_location.shape[0]),
# )
#
# ax.set_xlabel("5'UTR/CDS/3'UTR Metagene")
# ax.set_ylabel("Density")
# ax.axvline(1, alpha=0.3)
# ax.axvline(2, alpha=0.3)
# ax.set_xlim(0, 3)
# plt.legend()
#
# fig.savefig(os.path.join(output_dir, 'histogram_edits_metagene_density.svg'))

# %% [raw]
# fig, ax = plt.subplots(figsize=(15, 5))
# # sns.distplot(rps2_rel_location, ax=ax, hist_kws={"density":False}, bins=nbins, label='RPS2-Sample33', kde=False)
# # sns.distplot(apo_rel_location, ax=ax, hist_kws={"density":False}, bins=nbins, label='APOBEC-Sample5', kde=False)
# sns.distplot(rps2_rel_location, ax=ax, hist_kws={"density":False}, bins=nbins, label='RPS2-1000', kde=False)
# sns.distplot(apo_rel_location, ax=ax, hist_kws={"density":False}, bins=nbins, label='APOBEC-1000', kde=False)
# sns.distplot(rbfox2_rel_location, ax=ax, hist_kws={"density":False}, bins=nbins, label='RBFOX2-1000', kde=False)
# sns.distplot(etf1_rel_location, ax=ax, hist_kws={"density":False}, bins=nbins, label='ETF1-1000', kde=False)
# sns.distplot(gstp1_rel_location, ax=ax, hist_kws={"density":False}, bins=nbins, label='GSTP1-1000', kde=False)
# sns.distplot(abce1_rel_location, ax=ax, hist_kws={"density":False}, bins=nbins, label='ABCE1-1000', kde=False)
# # sns.distplot(rbfox2_rel_location, ax=ax, hist_kws={"density":False}, bins=nbins, label='RBFOX2-Sample19', kde=False)
#
# ax2 = ax.twinx()
# # sns.distplot(rps2_rel_location, ax=ax2, hist_kws={"density":True}, bins=nbins, label='RPS2-Sample33', hist=False)
# # sns.distplot(apo_rel_location, ax=ax2, hist_kws={"density":True}, bins=nbins, label='APOBEC-Sample5', hist=False)
# # sns.distplot(rbfox2_rel_location, ax=ax2, hist_kws={"density":True}, bins=nbins, label='RBFOX2-Sample19', hist=False)
# sns.distplot(rps2_rel_location, ax=ax2, hist_kws={"density":True}, bins=nbins, label='RPS2-1000', hist=False)
# sns.distplot(apo_rel_location, ax=ax2, hist_kws={"density":True}, bins=nbins, label='APOBEC-1000', hist=False)
# sns.distplot(rbfox2_rel_location, ax=ax2, hist_kws={"density":True}, bins=nbins, label='RBFOX2-1000', hist=False)
# sns.distplot(etf1_rel_location, ax=ax2, hist_kws={"density":True}, bins=nbins, label='ETF1-1000', hist=False)
# sns.distplot(gstp1_rel_location, ax=ax2, hist_kws={"density":True}, bins=nbins, label='GSTP1-1000', hist=False)
# sns.distplot(abce1_rel_location, ax=ax2, hist_kws={"density":True}, bins=nbins, label='ABCE1-1000', hist=False)
#
# ax.set_xlabel("Relative distance (5'UTR, CDS, 3'UTR)")
# ax.set_ylabel("Number of edits at {} confidence".format(conf))
#
# ax2.set_ylabel("Normalized density at {} confidence".format(conf))
# # fig.savefig(os.path.join(output_dir, 'metagene.svg'))

# %% [markdown]
# # Plot normalized and unnormalized histogram of region distribution of edit sites.
# - the n's are hardcoded from 06_rel_and_abs_dist_calc.sh

# %% [raw]
# fig, ax = plt.subplots(figsize=(15, 5))
# # sns.distplot(rps2_rel_location, ax=ax, hist_kws={"density":False}, bins=nbins, label='RPS2-Sample33', kde=False)
# # sns.distplot(apo_rel_location, ax=ax, hist_kws={"density":False}, bins=nbins, label='APOBEC-Sample5', kde=False)
# sns.distplot(rps2_rel_location, ax=ax, hist_kws={"density":False, 'alpha':0.1}, bins=nbins, label='RPS2-1000', kde=False)
# sns.distplot(apo_rel_location, ax=ax, hist_kws={"density":False, 'alpha':0.1}, bins=nbins, label='APOBEC-1000', kde=False)
# sns.distplot(rbfox2_rel_location, ax=ax, hist_kws={"density":False, 'alpha':0.1}, bins=nbins, label='RBFOX2-1000', kde=False)
# sns.distplot(etf1_rel_location, ax=ax, hist_kws={"density":False, 'alpha':0.1}, bins=nbins, label='ETF1-1000', kde=False)
# sns.distplot(gstp1_rel_location, ax=ax, hist_kws={"density":False, 'alpha':0.1}, bins=nbins, label='GSTP1-1000', kde=False)
# sns.distplot(abce1_rel_location, ax=ax, hist_kws={"density":False, 'alpha':0.1}, bins=nbins, label='ABCE1-1000', kde=False)
# # sns.distplot(rbfox2_rel_location, ax=ax, hist_kws={"density":False}, bins=nbins, label='RBFOX2-Sample19', kde=False)
#
# ax2 = ax.twinx()
# # sns.distplot(rps2_rel_location, ax=ax2, hist_kws={"density":True}, bins=nbins, label='RPS2-Sample33', hist=False)
# # sns.distplot(apo_rel_location, ax=ax2, hist_kws={"density":True}, bins=nbins, label='APOBEC-Sample5', hist=False)
# # sns.distplot(rbfox2_rel_location, ax=ax2, hist_kws={"density":True}, bins=nbins, label='RBFOX2-Sample19', hist=False)
# sns.distplot(rps2_rel_location, ax=ax2,  bins=nbins, label='RPS2-1000 (n={})'.format(rps2_rel_location.shape[0]), hist=False)
# sns.distplot(apo_rel_location, ax=ax2, bins=nbins, label='APOBEC-1000 (n={})'.format(apo_rel_location.shape[0]), hist=False, kde_kws={'alpha':0.3})
# sns.distplot(rbfox2_rel_location, ax=ax2, bins=nbins, label='RBFOX2-1000 (n={})'.format(rbfox2_rel_location.shape[0]), hist=False, kde_kws={'alpha':0.3})
# sns.distplot(etf1_rel_location, ax=ax2, bins=nbins, label='ETF1-1000 (n={})'.format(etf1_rel_location.shape[0]), hist=False, kde_kws={'alpha':0.3})
# sns.distplot(gstp1_rel_location, ax=ax2, bins=nbins, label='GSTP1-1000 (n={})'.format(gstp1_rel_location.shape[0]), hist=False, kde_kws={'alpha':0.3})
# sns.distplot(abce1_rel_location, ax=ax2, bins=nbins, label='ABCE1-1000 (n={})'.format(abce1_rel_location.shape[0]), hist=False, kde_kws={'alpha':0.3})
#
# ax.set_xlabel("Relative distance (5'UTR, CDS, 3'UTR)")
# ax.set_ylabel("Number of edits at {} confidence".format(conf))
#
# ax2.set_ylabel("Normalized density at {} confidence".format(conf))
# ax.set_xlim(0, 3)
#
# ax.axvline(1, alpha=0.3, color='grey')
# ax.axvline(2, alpha=0.3, color='grey')
# fig.savefig(os.path.join(output_dir, 'metagene_conf{}.svg'.format(conf)))
