# %% [markdown]
# # For this metagene plot, we're using Q1 genes from the boxplot figures.
# - This notebook uses python3-essential-tscc kernel

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import gffutils
import os
import glob
from collections import defaultdict

# %%
input_dir = '/home/bay001/projects/kris_apobec_20200121/permanent_data/final_analysis/figure_3/inputs'
output_dir = '/home/bay001/projects/kris_apobec_20200121/permanent_data/final_analysis/figure_3/inputs'

# %%
conf = 0.5
prefix = 'Q1' # IRES, Q1 or top200

# %%
all_beds = sorted(glob.glob(os.path.join(input_dir, '*.conf{}.bed'.format(conf))))
print(len(all_beds))
all_beds
# Out:
# 54
# ['/home/bay001/projects/kris_apobec_20200121/permanent_data/final_analysis/figure_3/inputs/ABCE1-1000_S15_L002_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf0.5.bed',
#  '/home/bay001/projects/kris_apobec_20200121/permanent_data/final_analysis/figure_3/inputs/APOBEC-STAMP_possorted_genome_bam-APOBEC_STAMP_Apo_filtered_lenti_common_expression_barcodes.txt.fx.conf0.5.bed',
#  '/home/bay001/projects/kris_apobec_20200121/permanent_data/final_analysis/figure_3/inputs/ApoControl-1000_S21_L002_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted.21M_a0_b0_e0.01.conf0.5.bed',
#  '/home/bay001/projects/kris_apobec_20200121/permanent_data/final_analysis/figure_3/inputs/ApoControl-1000_S21_L002_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf0.5.bed',
# ...

# %%
# bed2 = os.path.join(input_dir, 'hg19_annot.riboseq.{}.sorted.bed'.format(prefix))
bed2 = os.path.join(input_dir, 'hg19_annot.riboseq2.{}.sorted.bed'.format(prefix))

for bed in all_beds:
    # output_bed = os.path.join(output_dir, os.path.splitext(os.path.basename(bed))[0] + ".annotated.GSE112353_Riboseq.{}.bed".format(prefix))
    output_bed = os.path.join(output_dir, os.path.splitext(os.path.basename(bed))[0] + ".annotated.Riboseq2.{}.bed".format(prefix))
    cmd = 'module load bioperl;'
    cmd += 'perl metaPlotR/annotate_bed_file.pl --bed {} --bed2 {} > {}'.format(
        bed, 
        bed2,
        output_bed
    )
    print(cmd)
    # !$cmd
# Out:
# module load bioperl;perl metaPlotR/annotate_bed_file.pl --bed /home/bay001/projects/kris_apobec_20200121/permanent_data/final_analysis/figure_3/inputs/ABCE1-1000_S15_L002_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf0.5.bed --bed2 /home/bay001/projects/kris_apobec_20200121/permanent_data/final_analysis/figure_3/inputs/hg19_annot.riboseq2.Q1.sorted.bed > /home/bay001/projects/kris_apobec_20200121/permanent_data/final_analysis/figure_3/inputs/ABCE1-1000_S15_L002_R1_001.fastqTr.sorted.STARUnmapped.out.sorted.STARAligned.out.sorted_a0_b0_e0.01.conf0.5.annotated.Riboseq2.Q1.bed
# ...
