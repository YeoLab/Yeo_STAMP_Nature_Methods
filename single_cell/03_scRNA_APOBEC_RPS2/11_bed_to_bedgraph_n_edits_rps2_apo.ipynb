# %%
import pandas as pd
import numpy as np
import os
import glob

# %%
barcodes_file = '/home/bay001/projects/kris_apobec_20200121/permanent_data2/03_scRNA_APOBEC_RPS2/inputs/Top_100_apo_rps2_barcodes.xlsx'

tmp_dir = '/home/bay001/projects/kris_apobec_20200121/permanent_data2/03_scRNA_APOBEC_RPS2/tmp'
bed_dir = '/home/bay001/projects/kris_apobec_20200121/permanent_data2/03_scRNA_APOBEC_RPS2/sailor_outputs_individual_barcodes_merged_bedfiles/'
bedgraph_dir = '/home/bay001/projects/kris_apobec_20200121/permanent_data2/03_scRNA_APOBEC_RPS2/sailor_outputs_individual_barcodes_merged_bedgraphs'
output_dir = '/home/bay001/projects/kris_apobec_20200121/permanent_data2/03_scRNA_APOBEC_RPS2/outputs'

# %%
conf = 0.5
top = 100

# %%
apo_barcodes = pd.read_excel(barcodes_file, sheet_name='Sheet1')
apo_barcodes.sort_values(by=['n_edits'], ascending=False, inplace=True)
apo_barcodes.reset_index(drop=True, inplace=True)
apo_barcodes['rank'] = apo_barcodes.index + 1

rps2_barcodes = pd.read_excel(barcodes_file, sheet_name='Sheet2')
rps2_barcodes.sort_values(by=['n_edits'], ascending=False, inplace=True)
rps2_barcodes.reset_index(drop=True, inplace=True)
rps2_barcodes['rank'] = rps2_barcodes.index + 1

rps2_barcodes.head()
# Out:
#                                              barcode       class   n_edits  \
# 0  RPS2_possorted_genome_bam_MD-CGGCAGTGTGCGTGCT-...  RPS2-Edits  5.986034
# 1  RPS2_possorted_genome_bam_MD-ACTGTGATCAGACCGC-...  RPS2-Edits  4.031267
# 2  RPS2_possorted_genome_bam_MD-GACCCAGCACTTCAAG-...  RPS2-Edits  3.897882
# 3  RPS2_possorted_genome_bam_MD-CTCATCGGTCGAGCAA-...  RPS2-Edits  3.826919
# 4  RPS2_possorted_genome_bam_MD-ACAGCCGAGCCTGGAA-...  RPS2-Edits  3.793303
#
#          batch  rank
# 0  RPS2-fSTAMP     1
# 1  RPS2-fSTAMP     2
# 2  RPS2-fSTAMP     3
# 3  RPS2-fSTAMP     4
# 4  RPS2-fSTAMP     5

# %%
def get_sailor_bed_from_barcode_index(row, input_dir=bed_dir):
    barcode = row['barcode']
    bed = os.path.join(input_dir, '{}.bed'.format(barcode.replace('-Apo-Edits','').replace('-RPS2-Edits','')))
    assert os.path.exists(bed)
    return bed

# %%
apo_barcodes['bed'] = apo_barcodes.apply(get_sailor_bed_from_barcode_index, axis=1)
rps2_barcodes['bed'] = rps2_barcodes.apply(get_sailor_bed_from_barcode_index, axis=1)

rps2_barcodes.head()
# Out:
#                                              barcode       class   n_edits  \
# 0  RPS2_possorted_genome_bam_MD-CGGCAGTGTGCGTGCT-...  RPS2-Edits  5.986034
# 1  RPS2_possorted_genome_bam_MD-ACTGTGATCAGACCGC-...  RPS2-Edits  4.031267
# 2  RPS2_possorted_genome_bam_MD-GACCCAGCACTTCAAG-...  RPS2-Edits  3.897882
# 3  RPS2_possorted_genome_bam_MD-CTCATCGGTCGAGCAA-...  RPS2-Edits  3.826919
# 4  RPS2_possorted_genome_bam_MD-ACAGCCGAGCCTGGAA-...  RPS2-Edits  3.793303
#
#          batch  rank                                                bed
# 0  RPS2-fSTAMP     1  /home/bay001/projects/kris_apobec_20200121/per...
# 1  RPS2-fSTAMP     2  /home/bay001/projects/kris_apobec_20200121/per...
# 2  RPS2-fSTAMP     3  /home/bay001/projects/kris_apobec_20200121/per...
# 3  RPS2-fSTAMP     4  /home/bay001/projects/kris_apobec_20200121/per...
# 4  RPS2-fSTAMP     5  /home/bay001/projects/kris_apobec_20200121/per...

# %%
def calculate_edit_fraction(row):
    edited, total = row['score'].split(',')
    return int(edited)/float(total)

def bed_to_bedgraph(bed, bedgraph_output_file, bed_output_file, conf):
    df = pd.read_csv(bed, sep='\t', names=['chrom','start','end','name','score','strand'])
    df['chromfx'] = 'chr' + df['chrom'].astype(str)
    df['editfrac'] = df.apply(calculate_edit_fraction, axis=1)
    df = df[df['name'] >= conf]
    df[['chromfx','start','end','name','editfrac','strand']].to_csv(bed_output_file, sep='\t', index=False, header=False)
    df[['chromfx','start','end','editfrac']].to_csv(bedgraph_output_file, sep='\t', index=False, header=False)

# %%
for row in apo_barcodes.iterrows():
    output_file_prefix = os.path.join(bedgraph_dir, 'APOBEC-rank-{}.{}.n_edits{}.conf{}'.format(
        row[1]['rank'], row[1]['barcode'], row[1]['n_edits'], conf
    ))
    bedgraph_output_file = output_file_prefix + '.bedgraph'
    bed_output_file = output_file_prefix + '.bed'
    
    bed_to_bedgraph(row[1]['bed'], bedgraph_output_file, bed_output_file, conf)
    
for row in rps2_barcodes.iterrows():
    output_file_prefix = os.path.join(bedgraph_dir, 'RPS2-rank-{}.{}.n_edits{}.conf{}'.format(
        row[1]['rank'], row[1]['barcode'], row[1]['n_edits'], conf
    ))
    bedgraph_output_file = output_file_prefix + '.bedgraph'
    bed_output_file = output_file_prefix + '.bed'
    
    bed_to_bedgraph(row[1]['bed'], bedgraph_output_file, bed_output_file, conf)

# %%
rps2_barcodes
# Out:
#                                               barcode       class   n_edits  \
# 0   RPS2_possorted_genome_bam_MD-CGGCAGTGTGCGTGCT-...  RPS2-Edits  5.986034
# 1   RPS2_possorted_genome_bam_MD-ACTGTGATCAGACCGC-...  RPS2-Edits  4.031267
# 2   RPS2_possorted_genome_bam_MD-GACCCAGCACTTCAAG-...  RPS2-Edits  3.897882
# 3   RPS2_possorted_genome_bam_MD-CTCATCGGTCGAGCAA-...  RPS2-Edits  3.826919
# 4   RPS2_possorted_genome_bam_MD-ACAGCCGAGCCTGGAA-...  RPS2-Edits  3.793303
# 5   RPS2_possorted_genome_bam_MD-GGGAAGTTCCCATACC-...  RPS2-Edits  3.773452
# 6   RPS2_possorted_genome_bam_MD-AATAGAGCAGCTACAT-...  RPS2-Edits  3.760434
# 7   RPS2_possorted_genome_bam_MD-GCCAGCATCCTACGGG-...  RPS2-Edits  3.665949
# 8   RPS2_possorted_genome_bam_MD-ATGGTTGAGGTTCTTG-...  RPS2-Edits  3.652080
# 9   RPS2_possorted_genome_bam_MD-ACGTAGTAGCTTCGTA-...  RPS2-Edits  3.645473
# 10  RPS2_possorted_genome_bam_MD-ACACTGAGTGTTTACG-...  RPS2-Edits  3.622441
# 11  RPS2_possorted_genome_bam_MD-ATTCAGGCAGGCGAAT-...  RPS2-Edits  3.620693
# 12  RPS2_possorted_genome_bam_MD-TGTGTGAAGTTCCGGC-...  RPS2-Edits  3.591195
# 13  RPS2_possorted_genome_bam_MD-TAAGCCAGTCAGCTTA-...  RPS2-Edits  3.530628
# 14  RPS2_possorted_genome_bam_MD-GTAGGAGCAGTAACGG-...  RPS2-Edits  3.521687
# 15  RPS2_possorted_genome_bam_MD-GTGGCGTGTTGTAGCT-...  RPS2-Edits  3.501813
# 16  RPS2_possorted_genome_bam_MD-GCCAGGTGTTACACTG-...  RPS2-Edits  3.485296
# 17  RPS2_possorted_genome_bam_MD-ACACTGAGTTTAGTCG-...  RPS2-Edits  3.420116
# 18  RPS2_possorted_genome_bam_MD-AACAGGGCAAATAAGC-...  RPS2-Edits  3.397440
# 19  RPS2_possorted_genome_bam_MD-TCGCTTGCATCCTTGC-...  RPS2-Edits  3.371567
# 20  RPS2_possorted_genome_bam_MD-GATGGAGGTGAATGTA-...  RPS2-Edits  3.347086
# 21  RPS2_possorted_genome_bam_MD-GGGATCCAGGGATGTC-...  RPS2-Edits  3.288348
# 22  RPS2_possorted_genome_bam_MD-TTGAACGCACTGGACC-...  RPS2-Edits  3.283943
# 23  RPS2_possorted_genome_bam_MD-CTTCGGTGTCGAGCAA-...  RPS2-Edits  3.255656
# 24  RPS2_possorted_genome_bam_MD-TACGGGCCAGGTGTGA-...  RPS2-Edits  3.255173
# 25  RPS2_possorted_genome_bam_MD-AGGTCATTCCGTGGCA-...  RPS2-Edits  3.252295
# 26  RPS2_possorted_genome_bam_MD-CCAATTTAGAGTTGCG-...  RPS2-Edits  3.251893
# 27  RPS2_possorted_genome_bam_MD-AGGGTCCAGCTAGTTC-...  RPS2-Edits  3.251403
# 28  RPS2_possorted_genome_bam_MD-GGAATGGGTATAGGGC-...  RPS2-Edits  3.248732
# 29  RPS2_possorted_genome_bam_MD-TCGAACAAGTCATAGA-...  RPS2-Edits  3.247667
# ..                                                ...         ...       ...
# 70  RPS2_possorted_genome_bam_MD-GAAACCTAGAGTCAAT-...  RPS2-Edits  2.692338
# 71  RPS2_possorted_genome_bam_MD-GGTGAAGTCCATCGTC-...  RPS2-Edits  2.687922
# 72  RPS2_possorted_genome_bam_MD-GCCATTCAGAATAACC-...  RPS2-Edits  2.674429
# 73  RPS2_possorted_genome_bam_MD-GGTGGCTAGCACACCC-...  RPS2-Edits  2.668669
# 74  RPS2_possorted_genome_bam_MD-TCGTGGGGTCAAACGG-...  RPS2-Edits  2.667015
# 75  RPS2_possorted_genome_bam_MD-GATGACTAGGCATGCA-...  RPS2-Edits  2.653928
# 76  RPS2_possorted_genome_bam_MD-GACATCAGTGAGCCAA-...  RPS2-Edits  2.639502
# 77  RPS2_possorted_genome_bam_MD-CTGTGGGAGGCACAAC-...  RPS2-Edits  2.637384
# 78  RPS2_possorted_genome_bam_MD-GAGGGTAGTCGTTGGC-...  RPS2-Edits  2.628579
# 79  RPS2_possorted_genome_bam_MD-AAACCCAGTTCCGCAG-...  RPS2-Edits  2.610953
# 80  RPS2_possorted_genome_bam_MD-ACTTCCGTCGACCCAG-...  RPS2-Edits  2.610301
# 81  RPS2_possorted_genome_bam_MD-CAGATTGGTACTGCGC-...  RPS2-Edits  2.599894
# 82  RPS2_possorted_genome_bam_MD-GGGTAGAGTTTGGGAG-...  RPS2-Edits  2.591205
# 83  RPS2_possorted_genome_bam_MD-GTACAGTGTTATGTGC-...  RPS2-Edits  2.585721
# 84  RPS2_possorted_genome_bam_MD-AATGCCAGTGTGACCC-...  RPS2-Edits  2.577490
# 85  RPS2_possorted_genome_bam_MD-TTGTTTGGTCGGATTT-...  RPS2-Edits  2.574702
# 86  RPS2_possorted_genome_bam_MD-AAAGTCCCACGTACAT-...  RPS2-Edits  2.563004
# 87  RPS2_possorted_genome_bam_MD-CGAGAAGGTTTGCCGG-...  RPS2-Edits  2.562052
# 88  RPS2_possorted_genome_bam_MD-TGCCGAGCACGGTCTG-...  RPS2-Edits  2.558307
# 89  RPS2_possorted_genome_bam_MD-CCACAAACAATGGCAG-...  RPS2-Edits  2.557864
# 90  RPS2_possorted_genome_bam_MD-ACCATTTAGCAGGTCA-...  RPS2-Edits  2.554932
# 91  RPS2_possorted_genome_bam_MD-ACTGCAAAGCCTGAAG-...  RPS2-Edits  2.553447
# 92  RPS2_possorted_genome_bam_MD-ATTGGGTAGTGCACCC-...  RPS2-Edits  2.551239
# 93  RPS2_possorted_genome_bam_MD-CACGGGTCAGATTTCG-...  RPS2-Edits  2.550473
# 94  RPS2_possorted_genome_bam_MD-CTACCCAGTGTCATTG-...  RPS2-Edits  2.544219
# 95  RPS2_possorted_genome_bam_MD-TCCATCGTCCAAAGGG-...  RPS2-Edits  2.542006
# 96  RPS2_possorted_genome_bam_MD-AGCGATTTCGCTTGAA-...  RPS2-Edits  2.536466
# 97  RPS2_possorted_genome_bam_MD-TCGAACAGTCTGTGCG-...  RPS2-Edits  2.536017
# 98  RPS2_possorted_genome_bam_MD-TGAGACTGTTCGGCGT-...  RPS2-Edits  2.529700
# 99  RPS2_possorted_genome_bam_MD-ACAAAGAAGTCCCTAA-...  RPS2-Edits  2.528642
#
#              batch  rank                                                bed
# 0      RPS2-fSTAMP     1  /home/bay001/projects/kris_apobec_20200121/per...
# 1      RPS2-fSTAMP     2  /home/bay001/projects/kris_apobec_20200121/per...
# 2      RPS2-fSTAMP     3  /home/bay001/projects/kris_apobec_20200121/per...
# 3      RPS2-fSTAMP     4  /home/bay001/projects/kris_apobec_20200121/per...
# 4      RPS2-fSTAMP     5  /home/bay001/projects/kris_apobec_20200121/per...
# 5      RPS2-fSTAMP     6  /home/bay001/projects/kris_apobec_20200121/per...
# 6      RPS2-fSTAMP     7  /home/bay001/projects/kris_apobec_20200121/per...
# 7      RPS2-fSTAMP     8  /home/bay001/projects/kris_apobec_20200121/per...
# 8      RPS2-fSTAMP     9  /home/bay001/projects/kris_apobec_20200121/per...
# 9      RPS2-fSTAMP    10  /home/bay001/projects/kris_apobec_20200121/per...
# 10     RPS2-fSTAMP    11  /home/bay001/projects/kris_apobec_20200121/per...
# 11     RPS2-fSTAMP    12  /home/bay001/projects/kris_apobec_20200121/per...
# 12     RPS2-fSTAMP    13  /home/bay001/projects/kris_apobec_20200121/per...
# 13     RPS2-fSTAMP    14  /home/bay001/projects/kris_apobec_20200121/per...
# 14     RPS2-fSTAMP    15  /home/bay001/projects/kris_apobec_20200121/per...
# 15     RPS2-fSTAMP    16  /home/bay001/projects/kris_apobec_20200121/per...
# 16     RPS2-fSTAMP    17  /home/bay001/projects/kris_apobec_20200121/per...
# 17     RPS2-fSTAMP    18  /home/bay001/projects/kris_apobec_20200121/per...
# 18     RPS2-fSTAMP    19  /home/bay001/projects/kris_apobec_20200121/per...
# 19     RPS2-fSTAMP    20  /home/bay001/projects/kris_apobec_20200121/per...
# 20     RPS2-fSTAMP    21  /home/bay001/projects/kris_apobec_20200121/per...
# 21     RPS2-fSTAMP    22  /home/bay001/projects/kris_apobec_20200121/per...
# 22     RPS2-fSTAMP    23  /home/bay001/projects/kris_apobec_20200121/per...
# 23     RPS2-fSTAMP    24  /home/bay001/projects/kris_apobec_20200121/per...
# 24     RPS2-fSTAMP    25  /home/bay001/projects/kris_apobec_20200121/per...
# 25     RPS2-fSTAMP    26  /home/bay001/projects/kris_apobec_20200121/per...
# 26     RPS2-fSTAMP    27  /home/bay001/projects/kris_apobec_20200121/per...
# 27     RPS2-fSTAMP    28  /home/bay001/projects/kris_apobec_20200121/per...
# 28     RPS2-fSTAMP    29  /home/bay001/projects/kris_apobec_20200121/per...
# 29     RPS2-fSTAMP    30  /home/bay001/projects/kris_apobec_20200121/per...
# ..             ...   ...                                                ...
# 70     RPS2-fSTAMP    71  /home/bay001/projects/kris_apobec_20200121/per...
# 71  control-oSTAMP    72  /home/bay001/projects/kris_apobec_20200121/per...
# 72  control-oSTAMP    73  /home/bay001/projects/kris_apobec_20200121/per...
# 73  control-oSTAMP    74  /home/bay001/projects/kris_apobec_20200121/per...
# 74  control-oSTAMP    75  /home/bay001/projects/kris_apobec_20200121/per...
# 75     RPS2-fSTAMP    76  /home/bay001/projects/kris_apobec_20200121/per...
# 76  control-oSTAMP    77  /home/bay001/projects/kris_apobec_20200121/per...
# 77  control-oSTAMP    78  /home/bay001/projects/kris_apobec_20200121/per...
# 78  control-oSTAMP    79  /home/bay001/projects/kris_apobec_20200121/per...
# 79  control-oSTAMP    80  /home/bay001/projects/kris_apobec_20200121/per...
# 80  control-oSTAMP    81  /home/bay001/projects/kris_apobec_20200121/per...
# 81     RPS2-fSTAMP    82  /home/bay001/projects/kris_apobec_20200121/per...
# 82  control-oSTAMP    83  /home/bay001/projects/kris_apobec_20200121/per...
# 83  control-oSTAMP    84  /home/bay001/projects/kris_apobec_20200121/per...
# 84  control-oSTAMP    85  /home/bay001/projects/kris_apobec_20200121/per...
# 85     RPS2-fSTAMP    86  /home/bay001/projects/kris_apobec_20200121/per...
# 86     RPS2-fSTAMP    87  /home/bay001/projects/kris_apobec_20200121/per...
# 87  control-oSTAMP    88  /home/bay001/projects/kris_apobec_20200121/per...
# 88     RPS2-fSTAMP    89  /home/bay001/projects/kris_apobec_20200121/per...
# 89  control-oSTAMP    90  /home/bay001/projects/kris_apobec_20200121/per...
# 90  control-oSTAMP    91  /home/bay001/projects/kris_apobec_20200121/per...
# 91  control-oSTAMP    92  /home/bay001/projects/kris_apobec_20200121/per...
# 92     RPS2-fSTAMP    93  /home/bay001/projects/kris_apobec_20200121/per...
# 93  control-oSTAMP    94  /home/bay001/projects/kris_apobec_20200121/per...
# 94  control-oSTAMP    95  /home/bay001/projects/kris_apobec_20200121/per...
# 95     RPS2-fSTAMP    96  /home/bay001/projects/kris_apobec_20200121/per...
# 96  control-oSTAMP    97  /home/bay001/projects/kris_apobec_20200121/per...
# 97  control-oSTAMP    98  /home/bay001/projects/kris_apobec_20200121/per...
# 98     RPS2-fSTAMP    99  /home/bay001/projects/kris_apobec_20200121/per...
# 99     RPS2-fSTAMP   100  /home/bay001/projects/kris_apobec_20200121/per...
#
# [100 rows x 6 columns]
