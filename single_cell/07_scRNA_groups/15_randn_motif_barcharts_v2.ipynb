# %% [markdown]
# # Re-calculates p-values based on an existing motif.motif file and one or more outputs from analyze_motifs.py (from clip_analysis_legacy)

# %% [markdown]
# Edits were called from groups of randomly selected RBFOX2-capture sequence barcodes (n=1..49, 100, 200, 300, 400, 500, 600, 700, 800, 844) and processed as described in Figure 1F-H, resulting in a set of fasta sequences corresponding to each 51nt edit window as well as a corresponding random background. This was repeated 10 times. HOMER was then run on each of the 580 real/random sequences to find enriched de-novo motifs. The most significant motif that most resembled the canonical RBFOX2 motif (TGCATG) was then used as a pivot, and significance was re-calcuated for this motif for each foreground/background group and trial (findMotifs.pl foreground.fa fasta output/ -nofacts -p 4 -rna -S 20 -len 6 -noconvert -nogo -known -fasta background.fa -mknown TGCATG.motif).
#
# I did this in one batch using a wrapper script, found here:
# ```bash
# /home/bay001/projects/kris_apobec_20200121/scripts/recalculate_motif.py
# ```

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import glob
import os
from collections import defaultdict, OrderedDict
from tqdm import tnrange, tqdm_notebook

# %%
input_dir = '/home/bay001/projects/kris_apobec_20200121/permanent_data2/07_scRNA_groups/motifs_deep_recalc'
output_dir = '/home/bay001/projects/kris_apobec_20200121/permanent_data2/07_scRNA_groups/outputs'

# %%
prefix_to_clean = ['RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_possorted_genome_bam_MD-34_barcodes.', '.txt.fx.annotated.windows_51.e0.001_conf0.99']

# %%
df = pd.read_csv(os.path.join(input_dir, 'p-values.tsv'), sep='\t')
df.head()
# Out:
#                                           Unnamed: 0  \
# 0  RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_pos...
# 1  RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_pos...
# 2  RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_pos...
# 3  RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_pos...
# 4  RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_pos...
#
#                                           Motif Name Consensus       P-value  \
# 0  1-TGCATG,BestGuess:hsa-miR-3680* MIMAT0018107 ...    TGCATG  1.000000e-16
# 1  1-TGCATG,BestGuess:hsa-miR-3680* MIMAT0018107 ...    TGCATG  1.000000e-20
# 2  1-TGCATG,BestGuess:hsa-miR-3680* MIMAT0018107 ...    TGCATG  1.000000e-17
# 3  1-TGCATG,BestGuess:hsa-miR-3680* MIMAT0018107 ...    TGCATG  1.000000e-16
# 4  1-TGCATG,BestGuess:hsa-miR-3680* MIMAT0018107 ...    TGCATG  1.000000e-15
#
#    Log P-value  q-value (Benjamini)  # of Target Sequences with Motif  \
# 0       -36.89                  0.0                             485.0
# 1       -46.69                  0.0                             469.0
# 2       -40.87                  0.0                             518.0
# 3       -38.33                  0.0                             501.0
# 4       -36.66                  0.0                             451.0
#
#   % of Target Sequences with Motif  # of Background Sequences with Motif  \
# 0                           13.19%                                 848.5
# 1                           13.77%                                 760.5
# 2                           13.53%                                 899.7
# 3                           13.63%                                 878.4
# 4                           13.54%                                 772.1
#
#   % of Background Sequences with Motif
# 0                                8.37%
# 1                                8.08%
# 2                                8.49%
# 3                                8.64%
# 4                                8.44%

# %%
def nlog10p(row):
    if row['log10p'] == 0:
        return 0
    else:
        return -row['log10p']
    
df['rand'] = df['Unnamed: 0'].apply(lambda x: int(x.replace('RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_possorted_genome_bam_MD-34_barcodes.rand','').split('.')[0]))
df['trial'] = df['Unnamed: 0'].apply(lambda x: int(x.replace('RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_possorted_genome_bam_MD-34_barcodes.rand','').split('trial-')[1].replace('.txt.fx.annotated.windows_51.e0.001_conf0.99','')))
df['log10p'] = np.log10(df['P-value'])
df['-log10p'] = df.apply(nlog10p, axis=1)
df.sort_values(by=['rand', 'trial'], ascending=True)
# Out:
#                                             Unnamed: 0  \
# 110  RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_pos...
# 111  RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_pos...
# 112  RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_pos...
# 113  RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_pos...
# 114  RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_pos...
# 115  RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_pos...
# 116  RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_pos...
# 117  RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_pos...
# 118  RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_pos...
# 119  RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_pos...
# 230  RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_pos...
#
# 541  1.000000e-51    -117.8000               0.0000
# 542  1.000000e-52    -120.5000               0.0000
# 543  1.000000e-60    -138.3000               0.0000
# 544  1.000000e-50    -117.3000               0.0000
# 545  1.000000e-57    -133.4000               0.0000
# 546  1.000000e-49    -115.0000               0.0000
# 547  1.000000e-58    -133.8000               0.0000
# 548  1.000000e-59    -136.6000               0.0000
# 549  1.000000e-61    -140.7000               0.0000
# 550  1.000000e-50    -115.5000               0.0000
# 551  1.000000e-70    -161.6000               0.0000
# 552  1.000000e-54    -124.8000               0.0000
# 553  1.000000e-62    -143.0000               0.0000
# 554  1.000000e-56    -131.1000               0.0000
# 555  1.000000e-54    -125.9000               0.0000
# 556  1.000000e-58    -134.7000               0.0000
# 557  1.000000e-64    -148.4000               0.0000
# 558  1.000000e-53    -123.4000               0.0000
# 559  1.000000e-56    -131.1000               0.0000
#
#      # of Target Sequences with Motif % of Target Sequences with Motif  \
# 110                               9.0                           18.75%
# 111                               0.0                               0%
# 112                               2.0                           12.50%
# 113                               2.0                            5.41%
# 114                               7.0                           15.56%
# 115                               0.0                               0%
# 116                               2.0                           25.00%
# 117                               3.0                           12.00%
# 118                               6.0                           19.35%
# 119                               3.0                           11.11%
# 230                              14.0                           14.89%
# 231                              15.0                           16.48%
# 232                               8.0                           11.11%
# 233                              18.0                           13.14%
# 234                              18.0                           13.85%
# 235                              10.0                           10.00%
# 236                              11.0                            9.91%
# 237                              18.0                           15.13%
# 238                              14.0                           12.17%
# 239                               4.0                            8.51%
# 350                              15.0                           13.16%
# 351                              19.0                           15.32%
# 352                               6.0                            9.68%
# 353                              17.0                           14.41%
# 354                              26.0                           13.54%
# 355                              10.0                            8.77%
# 356                              22.0                           13.92%
# 357                              24.0                           12.24%
# 358                               6.0                           16.67%
# 359                              12.0                           13.48%
# ..                                ...                              ...
# 520                            1528.0                           14.86%
# 521                            1557.0                           14.86%
# 522                            1545.0                           14.84%
# 523                            1529.0                           14.93%
# 524                            1521.0                           14.68%
# 525                            1505.0                           14.67%
# 526                            1524.0                           14.80%
# 527                            1540.0                           14.85%
# 528                            1548.0                           15.11%
# 529                            1499.0                           14.17%
# 540                            1602.0                           15.15%
# 541                            1611.0                           15.11%
# 542                            1609.0                           15.12%
# 543                            1613.0                           15.19%
# 544                            1608.0                           15.11%
# 545                            1612.0                           15.13%
# 546                            1613.0                           15.14%
# 547                            1615.0                           15.16%
# 548                            1609.0                           15.10%
# 549                            1615.0                           15.14%
# 550                            1644.0                           15.11%
# 551                            1644.0                           15.11%
# 552                            1644.0                           15.11%
# 553                            1644.0                           15.11%
# 554                            1644.0                           15.11%
# 555                            1644.0                           15.11%
# 556                            1644.0                           15.11%
# 557                            1644.0                           15.11%
# 558                            1644.0                           15.11%
# 559                            1644.0                           15.11%
#
#      # of Background Sequences with Motif  \
# 110                                  10.5
# 111                                   0.0
# 112                                   4.5
# 113                                   3.6
# 114                                   5.4
# 115                                   0.0
# 116                                   4.2
# 117                                   6.2
# 118                                   8.9
# 119                                   2.9
# 230                                  22.3
# 231                                  14.2
# 232                                  11.3
# 233                                  30.9
# 234                                  23.5
# 235                                  12.7
# 236                                  25.6
# 237                                  15.9
# 238                                  11.7
# 239                                   3.4
# 350                                  18.0
# 351                                  27.5
# 352                                   6.0
# 353                                  22.2
# 354                                  39.7
# 355                                  15.7
# 356                                  22.1
# 357                                  36.2
# 358                                   6.3
# 359                                  10.8
# ..                                    ...
# 520                                2460.4
# 521                                2610.4
# 522                                2569.4
# 523                                2604.6
# 524                                2496.7
# 525                                2544.2
# 526                                2559.4
# 527                                2643.0
# 528                                2517.1
# 529                                2784.1
# 540                                2708.6
# 541                                2796.4
# 542                                2782.9
# 543                                2674.5
# 544                                2796.9
# 545                                2698.9
# 546                                2811.9
# 547                                2713.6
# 548                                2680.6
# 549                                2697.5
# 550                                2884.4
# 551                                2620.8
# 552                                2828.1
# 553                                2722.9
# 554                                2788.8
# 555                                2825.9
# 556                                2774.4
# 557                                2687.5
# 558                                2846.1
# 559                                2780.0
#
#     % of Background Sequences with Motif  rand  trial  log10p  -log10p
# 110                                7.99%     1      0    -1.0      1.0
# 111                                   0%     1      1     0.0      0.0
# 112                                9.63%     1      2     0.0      0.0
# 113                                3.69%     1      3     0.0      0.0
# 114                                4.66%     1      4    -1.0      1.0
# 115                                   0%     1      5     0.0      0.0
# 116                               17.09%     1      6     0.0      0.0
# 117                                9.58%     1      7     0.0      0.0
# 118                               10.63%     1      8     0.0      0.0
# 119                                4.27%     1      9     0.0      0.0
# 230                                8.60%     2      0    -1.0      1.0
# 231                                5.55%     2      1    -2.0      2.0
# 232                                5.76%     2      2     0.0      0.0
# 233                                8.43%     2      3    -1.0      1.0
# 234                                7.00%     2      4    -1.0      1.0
# 235                                4.89%     2      5    -1.0      1.0
# 236                                8.46%     2      6     0.0      0.0
# 237                                5.04%     2      7    -3.0      3.0
# 238                                3.95%     2      8    -2.0      2.0
# 239                                2.71%     2      9    -1.0      1.0
# 350                                5.80%     3      0    -2.0      2.0
# 351                                8.23%     3      1    -1.0      1.0
# 352                                3.93%     3      2    -1.0      1.0
# 353                                7.21%     3      3    -1.0      1.0
# 354                                7.41%     3      4    -2.0      2.0
# 355                                5.44%     3      5     0.0      0.0
# 356                                4.91%     3      6    -3.0      3.0
# 357                                6.73%     3      7    -1.0      1.0
# 358                                6.67%     3      8    -1.0      1.0
# 359                                4.41%     3      9    -2.0      2.0
# ..                                   ...   ...    ...     ...      ...
# 520                                8.74%   700      0   -63.0     63.0
# 521                                9.05%   700      1   -57.0     57.0
# 522                                9.05%   700      2   -56.0     56.0
# 523                                9.27%   700      3   -52.0     52.0
# 524                                8.81%   700      4   -58.0     58.0
# 525                                9.10%   700      5   -51.0     51.0
# 526                                9.03%   700      6   -55.0     55.0
# 527                                9.30%   700      7   -51.0     51.0
# 528                                9.01%   700      8   -61.0     61.0
# 529                                9.63%   700      9   -35.0     35.0
# 540                                9.40%   800      0   -55.0     55.0
# 541                                9.58%   800      1   -51.0     51.0
# 542                                9.54%   800      2   -52.0     52.0
# 543                                9.23%   800      3   -60.0     60.0
# 544                                9.60%   800      4   -50.0     50.0
# 545                                9.28%   800      5   -57.0     57.0
# 546                                9.67%   800      6   -49.0     49.0
# 547                                9.30%   800      7   -58.0     58.0
# 548                                9.20%   800      8   -59.0     59.0
# 549                                9.16%   800      9   -61.0     61.0
# 550                                9.69%   844      0   -50.0     50.0
# 551                                8.81%   844      1   -70.0     70.0
# 552                                9.49%   844      2   -54.0     54.0
# 553                                9.14%   844      3   -62.0     62.0
# 554                                9.37%   844      4   -56.0     56.0
# 555                                9.47%   844      5   -54.0     54.0
# 556                                9.30%   844      6   -58.0     58.0
# 557                                9.04%   844      7   -64.0     64.0
# 558                                9.52%   844      8   -53.0     53.0
# 559                                9.37%   844      9   -56.0     56.0
#
# [580 rows x 14 columns]

# %%
df.sort_values(by='rand', ascending=True).loc[110] # [['Unnamed: 0']].values
# Out:
# Unnamed: 0                              RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_pos...
# Motif Name                              1-TGCATG,BestGuess:hsa-miR-3680* MIMAT0018107 ...
# Consensus                                                                          TGCATG
# P-value                                                                               0.1
# Log P-value                                                                        -3.344
# q-value (Benjamini)                                                                0.0353
# # of Target Sequences with Motif                                                        9
# % of Target Sequences with Motif                                                   18.75%
# # of Background Sequences with Motif                                                 10.5
# % of Background Sequences with Motif                                                7.99%
# rand                                                                                    1
# trial                                                                                   0
# log10p                                                                                 -1
# -log10p                                                                                 1
# Name: 110, dtype: object

# %%
df.sort_values(by='rand', ascending=True).loc[239]# [['Unnamed: 0']].values
# Out:
# Unnamed: 0                              RBFOX2-TIA1-STAMP_round2E_read1_feature_FB_pos...
# Motif Name                              1-TGCATG,BestGuess:hsa-miR-3680* MIMAT0018107 ...
# Consensus                                                                          TGCATG
# P-value                                                                               0.1
# Log P-value                                                                        -2.412
# q-value (Benjamini)                                                                0.0896
# # of Target Sequences with Motif                                                        4
# % of Target Sequences with Motif                                                    8.51%
# # of Background Sequences with Motif                                                  3.4
# % of Background Sequences with Motif                                                2.71%
# rand                                                                                    2
# trial                                                                                   9
# log10p                                                                                 -1
# -log10p                                                                                 1
# Name: 239, dtype: object

# %%
fig, ax = plt.subplots(figsize=(25, 10))
sns.lineplot(x="rand", y="-log10p", data=df, ax=ax)
fig.savefig(os.path.join(output_dir, 'recalculate_motifs_line.basedon-844-1.png'))
fig.savefig(os.path.join(output_dir, 'recalculate_motifs_line.basedon-844-1.svg'))

# %%
fig, ax = plt.subplots(figsize=(25, 10))
sns.barplot(x="rand", y="-log10p", data=df, ax=ax)
fig.savefig(os.path.join(output_dir, 'recalculate_motifs.basedon-844-1.png'))
fig.savefig(os.path.join(output_dir, 'recalculate_motifs.basedon-844-1.svg'))
